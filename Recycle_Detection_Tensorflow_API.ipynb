# %% [markdown]
# <a href="https://colab.research.google.com/github/Aida81/Recycle-Item-Detection/blob/main/Recycle_Detection_Tensorflow_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training an Object Detection Model for Raspberry Pi with TensorFlow API using Google COLAB
#
#   This Colab is for training a Tensorflow Model used to detect Recycle Item which is fully trained in Google Colab on Tensorflow 1.13 and then converted to a TFLite model to be used on the Raspberry Pi.
#
#   The Colab here could be easily converted to training any other type of visual detector using the same basic functions but with a different set of labeled images and just changes to the config file and label map files in the training folder.
#
#   Therefore, I am training it with my own dataset which 6 classes of Recycle Item consists of cardboard, glass, paper, metal, plastic and trash.

# %% [markdown]
# # Install the version of Tensorflow for this model
#
# Tensorflow GPU v1.13 had been used and this section shows the steps to setup the tensorflow.

# %%
# Uninstall current tensorflow, make sure that you confirm at this step, 
# because it will ask if you are sure
# !pip uninstall tensorflow
# Out:
# WARNING: Skipping tensorflow as it is not installed.

# %% [markdown]
# Install Tensorflow-GPU v1.13

# %%
# !pip install tensorflow-gpu==1.13.2
# Out:
# Requirement already satisfied: tensorflow-gpu==1.13.2 in /usr/local/lib/python3.6/dist-packages (1.13.2)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (1.13.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (0.3.3)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (1.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (0.8.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (1.32.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (1.19.5)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (0.10.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (3.12.4)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (0.36.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.2) (1.15.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.2) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.2) (3.3.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.2) (2.10.0)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow-gpu==1.13.2) (4.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.13.2) (51.3.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.2) (3.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.2) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.2) (3.7.4.3)

# %% [markdown]
# Check python version, should be Python 3.6.9

# %%
# !python --version
# Out:
# Python 3.6.9

# %% [markdown]
# Verify installed Tensorflow

# %%
import tensorflow as tf
print (tf.__version__)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.13.2

# %%
from google.colab import drive
drive.mount ('/content/gdrive')

# %%
# show current directory
# !pwd
# Out:
# /content

# %% [markdown]
# Next download the model archive that contains the object detection model example. We need to specifically use the version 1.13 to match the version of Tensorflow that we just installed

# %%
# Get Tensorflow from GitHub and unzip it
# !cd /content
# !mkdir tensorflow1
# !cd /content/tensorflow1
# !wget https://github.com/tensorflow/models/archive/r1.13.0.zip
# !unzip -q ./r1.13.0.zip
# !mv models-r1.13.0/ tensorflow1/models/
# !rm r1.13.0.zip
# Out:
# --2021-01-29 04:01:33--  https://github.com/tensorflow/models/archive/r1.13.0.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/tensorflow/models/zip/r1.13.0 [following]
# --2021-01-29 04:01:33--  https://codeload.github.com/tensorflow/models/zip/r1.13.0
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘r1.13.0.zip’
#
# r1.13.0.zip             [<=>                 ] 420.44M  18.8MB/s    in 25s
#
# 2021-01-29 04:01:58 (16.9 MB/s) - ‘r1.13.0.zip’ saved [440860285]

# %% [markdown]
# Build and install the Libraries needed to run the example object_detection code

# %%
# Build and Install Tensorflow
# !python /content/tensorflow1/models/research/setup.py build
# !python /content/tensorflow1/models/research/setup.py install
# Out:
# running build
# running install
# running bdist_egg
# running egg_info
# creating object_detection.egg-info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# reading manifest file 'object_detection.egg-info/SOURCES.txt'
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# creating build
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying object_detection.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/object_detection-0.1-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing object_detection-0.1-py3.6.egg
# Copying object_detection-0.1-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding object-detection 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg
# Processing dependencies for object-detection==0.1
# Searching for Cython==0.29.21
# Best match: Cython 0.29.21
# Adding Cython 0.29.21 to easy-install.pth file
# Installing cygdb script to /usr/local/bin
# Installing cython script to /usr/local/bin
# Installing cythonize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for matplotlib==3.2.2
# Best match: matplotlib 3.2.2
# Adding matplotlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Pillow==7.0.0
# Best match: Pillow 7.0.0
# Adding Pillow 7.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for kiwisolver==1.3.1
# Best match: kiwisolver 1.3.1
# Adding kiwisolver 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for cycler==0.10.0
# Best match: cycler 0.10.0
# Adding cycler 0.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pyparsing==2.4.7
# Best match: pyparsing 2.4.7
# Adding pyparsing 2.4.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for python-dateutil==2.8.1
# Best match: python-dateutil 2.8.1
# Adding python-dateutil 2.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for object-detection==0.1

# %% [markdown]
# Change to the /research folder and build the protos for later use

# %%
# Go into research/ DIR of Tensorflow
# %cd /content/tensorflow1/models/research/

# Build protos!
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/tensorflow1/models/research

# %% [markdown]
# Set the PYTHONPATH environmental variable

# %%
# Set PYTHONPATH
# %set_env PYTHONPATH=/content/tensorflow1/models:/content/tensorflow1/models/research:/content/tensorflow1/models/research/slim:/content/tensorflow1/models:/content/tensorflow1/models/research/object_detection
# Out:
# env: PYTHONPATH=/content/tensorflow1/models:/content/tensorflow1/models/research:/content/tensorflow1/models/research/slim:/content/tensorflow1/models:/content/tensorflow1/models/research/object_detection

# %% [markdown]
# Move to the object_detection folder, where you will do most of the remaining work

# %%
# Go into object_detection/ DIR of Tensorflow
# %cd object_detection
# Out:
# /content/tensorflow1/models/research/object_detection

# %% [markdown]
# Run this if want to know how much time left for current colab session

# %%
import time, psutil
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600)
# Out:
# Time remaining for this session is:  11.713671231004927

# %% [markdown]
# # Model

# %% [markdown]
# Download the pretrained Quantized MobileNet V2 Coco model. You will need the quantized model so that it can run using the Google Coral USB modelue for faster calculation on the Raspberry Pi.

# %%
# Now get SSD mobilenet model from GitHub
# !wget http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz
# !tar -xf ./ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz
# !rm ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz
# Out:
# --2021-01-29 04:02:04--  http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.31.128, 2607:f8b0:4004:806::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.31.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 144806142 (138M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz’
#
# ssd_mobilenet_v2_qu 100%[===================>] 138.10M   137MB/s    in 1.0s
#
# 2021-01-29 04:02:05 (137 MB/s) - ‘ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03.tar.gz’ saved [144806142/144806142]

# %% [markdown]
# Download and zip dataset that had been upload in github. The image dataset already annotate by using Classifai and save in .xml file for each image. Then, they also had been splitted into train and test with their own xml file. The image had been converted to tflite file.

# %%
! git clone https://github.com/Aida81/Recycle-Item-Detection.git
# Out:
# Cloning into 'Recycle-Item-Detection'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 33 (delta 9), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (33/33), done.

# %% [markdown]
# Change a few line according to the dataset path and class in ssd_mobilenet_v1_quantized_300x300_coco.config
#
# 1. Line 9 : num_classes: 6
# 2. Line 156 : fine_tune_checkpoint: "ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/model.ckpt" # Path to extracted files of pre-trained model
# 3.Line 175 :  input_path for training: "training/train.record" # Path to training TFRecord file
# 4. Line 187 : input_path for evaluation: "training/test.record" # Path to test TFRecord file
# 5. Line 177 & 191 :  label_map_path: "training/label_map.pbtxt" # Path to label map file

# %% [markdown]
# Create folder to hold the test and training images

# %%
# !mkdir images

# %% [markdown]
# Copy the RecycleItem.zip file into the /images directory, unzip the file and then delete the zip file

# %%
# !cp /content/tensorflow1/models/research/object_detection/Recycle-Item-Detection/RecycleItem.zip images/ 
# !unzip Recycle-Item-Detection/RecycleItemImage.zip -d images
# !rm Recycle-Item-Detection/RecycleItemImage.zip
# Out:
# Archive:  Recycle-Item-Detection/RecycleItemImage.zip
#    creating: images/Recycle Item Image/
#    creating: images/Recycle Item Image/test/
#   inflating: images/Recycle Item Image/test/recycle0004.jpg
#   inflating: images/Recycle Item Image/test/recycle0004_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0005.jpg
#   inflating: images/Recycle Item Image/test/recycle0005_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0006.jpg
#   inflating: images/Recycle Item Image/test/recycle0006_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0007.jpg
#   inflating: images/Recycle Item Image/test/recycle0007_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0008.jpg
#   inflating: images/Recycle Item Image/test/recycle0008_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0011.jpg
#   inflating: images/Recycle Item Image/test/recycle0011_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0012.jpg
#   inflating: images/Recycle Item Image/test/recycle0012_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0013.jpg
#   inflating: images/Recycle Item Image/test/recycle0013_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0014.jpg
#   inflating: images/Recycle Item Image/test/recycle0014_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0016.jpg
#   inflating: images/Recycle Item Image/test/recycle0016_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0017.jpg
#   inflating: images/Recycle Item Image/test/recycle0017_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0018.jpg
#   inflating: images/Recycle Item Image/test/recycle0018_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0019.jpg
#   inflating: images/Recycle Item Image/test/recycle0019_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0020.jpg
#   inflating: images/Recycle Item Image/test/recycle0020_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0021.jpg
#   inflating: images/Recycle Item Image/test/recycle0021_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0022.jpg
#   inflating: images/Recycle Item Image/test/recycle0022_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0025.jpg
#   inflating: images/Recycle Item Image/test/recycle0025_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0026.jpg
#   inflating: images/Recycle Item Image/test/recycle0026_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0029.jpg
#   inflating: images/Recycle Item Image/test/recycle0029_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0030.jpg
#   inflating: images/Recycle Item Image/test/recycle0030_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0032.jpg
#   inflating: images/Recycle Item Image/test/recycle0032_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0033.jpg
#   inflating: images/Recycle Item Image/test/recycle0033_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0034.jpg
#   inflating: images/Recycle Item Image/test/recycle0034_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0035.jpg
#   inflating: images/Recycle Item Image/test/recycle0035_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0036.jpg
#   inflating: images/Recycle Item Image/test/recycle0036_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0037.jpg
#   inflating: images/Recycle Item Image/test/recycle0037_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0038.jpg
#   inflating: images/Recycle Item Image/test/recycle0038_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0040.jpg
#   inflating: images/Recycle Item Image/test/recycle0040_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0041.jpg
#   inflating: images/Recycle Item Image/test/recycle0041_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0043.jpg
#   inflating: images/Recycle Item Image/test/recycle0043_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0045.jpg
#   inflating: images/Recycle Item Image/test/recycle0045_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0049.jpg
#   inflating: images/Recycle Item Image/test/recycle0049_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0051.jpg
#   inflating: images/Recycle Item Image/test/recycle0051_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0052.jpg
#   inflating: images/Recycle Item Image/test/recycle0052_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0053.jpg
#   inflating: images/Recycle Item Image/test/recycle0053_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0054.jpg
#   inflating: images/Recycle Item Image/test/recycle0054_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0056.jpg
#   inflating: images/Recycle Item Image/test/recycle0056_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0059.jpg
#   inflating: images/Recycle Item Image/test/recycle0059_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0060.jpg
#   inflating: images/Recycle Item Image/test/recycle0060_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0062.jpg
#   inflating: images/Recycle Item Image/test/recycle0062_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0063.jpg
#   inflating: images/Recycle Item Image/test/recycle0063_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0064.jpg
#   inflating: images/Recycle Item Image/test/recycle0064_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0065.jpg
#   inflating: images/Recycle Item Image/test/recycle0065_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0068.jpg
#   inflating: images/Recycle Item Image/test/recycle0068_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0070.jpg
#   inflating: images/Recycle Item Image/test/recycle0070_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0071.jpg
#   inflating: images/Recycle Item Image/test/recycle0071_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0072.jpg
#   inflating: images/Recycle Item Image/test/recycle0072_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0073.jpg
#   inflating: images/Recycle Item Image/test/recycle0073_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0075.jpg
#   inflating: images/Recycle Item Image/test/recycle0075_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0078.jpg
#   inflating: images/Recycle Item Image/test/recycle0078_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0079.jpg
#   inflating: images/Recycle Item Image/test/recycle0079_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0081.jpg
#   inflating: images/Recycle Item Image/test/recycle0081_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0084.jpg
#   inflating: images/Recycle Item Image/test/recycle0084_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0087.jpg
#   inflating: images/Recycle Item Image/test/recycle0087_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0088.jpg
#   inflating: images/Recycle Item Image/test/recycle0088_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0089.jpg
#   inflating: images/Recycle Item Image/test/recycle0089_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0090.jpg
#   inflating: images/Recycle Item Image/test/recycle0090_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0092.jpg
#   inflating: images/Recycle Item Image/test/recycle0092_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0093.jpg
#   inflating: images/Recycle Item Image/test/recycle0093_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0094.jpg
#   inflating: images/Recycle Item Image/test/recycle0094_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0097.jpg
#   inflating: images/Recycle Item Image/test/recycle0097_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0098.jpg
#   inflating: images/Recycle Item Image/test/recycle0098_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0100.jpg
#   inflating: images/Recycle Item Image/test/recycle0100_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0103.jpg
#   inflating: images/Recycle Item Image/test/recycle0103_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0104.jpg
#   inflating: images/Recycle Item Image/test/recycle0104_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0105.jpg
#   inflating: images/Recycle Item Image/test/recycle0105_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0107.jpg
#   inflating: images/Recycle Item Image/test/recycle0107_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0108.jpg
#   inflating: images/Recycle Item Image/test/recycle0108_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0110.jpg
#   inflating: images/Recycle Item Image/test/recycle0110_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0112.jpg
#   inflating: images/Recycle Item Image/test/recycle0112_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0114.jpg
#   inflating: images/Recycle Item Image/test/recycle0114_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0115.jpg
#   inflating: images/Recycle Item Image/test/recycle0115_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0116.jpg
#   inflating: images/Recycle Item Image/test/recycle0116_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0117.jpg
#   inflating: images/Recycle Item Image/test/recycle0117_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0118.jpg
#   inflating: images/Recycle Item Image/test/recycle0118_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0119.jpg
#   inflating: images/Recycle Item Image/test/recycle0119_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0120.jpg
#   inflating: images/Recycle Item Image/test/recycle0120_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0121.jpg
#   inflating: images/Recycle Item Image/test/recycle0121_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0123.jpg
#   inflating: images/Recycle Item Image/test/recycle0123_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0124.jpg
#   inflating: images/Recycle Item Image/test/recycle0124_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0126.jpg
#   inflating: images/Recycle Item Image/test/recycle0126_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0127.jpg
#   inflating: images/Recycle Item Image/test/recycle0127_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0128.jpg
#   inflating: images/Recycle Item Image/test/recycle0128_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0129.jpg
#   inflating: images/Recycle Item Image/test/recycle0129_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0132.jpg
#   inflating: images/Recycle Item Image/test/recycle0132_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0133.jpg
#   inflating: images/Recycle Item Image/test/recycle0133_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0134.jpg
#   inflating: images/Recycle Item Image/test/recycle0134_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0135.jpg
#   inflating: images/Recycle Item Image/test/recycle0135_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0136.jpg
#   inflating: images/Recycle Item Image/test/recycle0136_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0139.jpg
#   inflating: images/Recycle Item Image/test/recycle0139_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0140.jpg
#   inflating: images/Recycle Item Image/test/recycle0140_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0145.jpg
#   inflating: images/Recycle Item Image/test/recycle0145_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0149.jpg
#   inflating: images/Recycle Item Image/test/recycle0149_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0151.jpg
#   inflating: images/Recycle Item Image/test/recycle0151_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0152.jpg
#   inflating: images/Recycle Item Image/test/recycle0152_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0153.jpg
#   inflating: images/Recycle Item Image/test/recycle0153_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0157.jpg
#   inflating: images/Recycle Item Image/test/recycle0157_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0158.jpg
#   inflating: images/Recycle Item Image/test/recycle0158_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0161.jpg
#   inflating: images/Recycle Item Image/test/recycle0161_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0162.jpg
#   inflating: images/Recycle Item Image/test/recycle0162_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0163.jpg
#   inflating: images/Recycle Item Image/test/recycle0163_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0164.jpg
#   inflating: images/Recycle Item Image/test/recycle0164_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0166.jpg
#   inflating: images/Recycle Item Image/test/recycle0166_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0168.jpg
#   inflating: images/Recycle Item Image/test/recycle0168_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0169.jpg
#   inflating: images/Recycle Item Image/test/recycle0169_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0170.jpg
#   inflating: images/Recycle Item Image/test/recycle0170_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0171.jpg
#   inflating: images/Recycle Item Image/test/recycle0171_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0173.jpg
#   inflating: images/Recycle Item Image/test/recycle0173_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0178.jpg
#   inflating: images/Recycle Item Image/test/recycle0178_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0179.jpg
#   inflating: images/Recycle Item Image/test/recycle0179_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0180.jpg
#   inflating: images/Recycle Item Image/test/recycle0180_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0181.jpg
#   inflating: images/Recycle Item Image/test/recycle0181_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0183.jpg
#   inflating: images/Recycle Item Image/test/recycle0183_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0185.jpg
#   inflating: images/Recycle Item Image/test/recycle0185_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0186.jpg
#   inflating: images/Recycle Item Image/test/recycle0186_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0187.jpg
#   inflating: images/Recycle Item Image/test/recycle0187_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0188.jpg
#   inflating: images/Recycle Item Image/test/recycle0188_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0189.jpg
#   inflating: images/Recycle Item Image/test/recycle0189_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0190.jpg
#   inflating: images/Recycle Item Image/test/recycle0190_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0191.jpg
#   inflating: images/Recycle Item Image/test/recycle0191_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0192.jpg
#   inflating: images/Recycle Item Image/test/recycle0192_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0193.jpg
#   inflating: images/Recycle Item Image/test/recycle0193_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0196.jpg
#   inflating: images/Recycle Item Image/test/recycle0196_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0198.jpg
#   inflating: images/Recycle Item Image/test/recycle0198_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0200.jpg
#   inflating: images/Recycle Item Image/test/recycle0200_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0204.jpg
#   inflating: images/Recycle Item Image/test/recycle0204_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0205.jpg
#   inflating: images/Recycle Item Image/test/recycle0205_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0207.jpg
#   inflating: images/Recycle Item Image/test/recycle0207_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0209.jpg
#   inflating: images/Recycle Item Image/test/recycle0209_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0210.jpg
#   inflating: images/Recycle Item Image/test/recycle0210_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0211.jpg
#   inflating: images/Recycle Item Image/test/recycle0211_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0212.jpg
#   inflating: images/Recycle Item Image/test/recycle0212_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0214.jpg
#   inflating: images/Recycle Item Image/test/recycle0214_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0216.jpg
#   inflating: images/Recycle Item Image/test/recycle0216_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0217.jpg
#   inflating: images/Recycle Item Image/test/recycle0217_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0218.jpg
#   inflating: images/Recycle Item Image/test/recycle0218_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0220.jpg
#   inflating: images/Recycle Item Image/test/recycle0220_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0221.jpg
#   inflating: images/Recycle Item Image/test/recycle0221_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0222.jpg
#   inflating: images/Recycle Item Image/test/recycle0222_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0223.jpg
#   inflating: images/Recycle Item Image/test/recycle0223_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0225.jpg
#   inflating: images/Recycle Item Image/test/recycle0225_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0227.jpg
#   inflating: images/Recycle Item Image/test/recycle0227_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0228.jpg
#   inflating: images/Recycle Item Image/test/recycle0228_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0229.jpg
#   inflating: images/Recycle Item Image/test/recycle0229_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0230.jpg
#   inflating: images/Recycle Item Image/test/recycle0230_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0232.jpg
#   inflating: images/Recycle Item Image/test/recycle0232_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0233.jpg
#   inflating: images/Recycle Item Image/test/recycle0233_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0234.jpg
#   inflating: images/Recycle Item Image/test/recycle0234_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0235.jpg
#   inflating: images/Recycle Item Image/test/recycle0235_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0236.jpg
#   inflating: images/Recycle Item Image/test/recycle0236_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0237.jpg
#   inflating: images/Recycle Item Image/test/recycle0237_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0239.jpg
#   inflating: images/Recycle Item Image/test/recycle0239_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0240.jpg
#   inflating: images/Recycle Item Image/test/recycle0240_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0242.jpg
#   inflating: images/Recycle Item Image/test/recycle0242_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0243.jpg
#   inflating: images/Recycle Item Image/test/recycle0243_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0245.jpg
#   inflating: images/Recycle Item Image/test/recycle0245_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0248.jpg
#   inflating: images/Recycle Item Image/test/recycle0248_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0249.jpg
#   inflating: images/Recycle Item Image/test/recycle0249_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0250.jpg
#   inflating: images/Recycle Item Image/test/recycle0250_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0251.jpg
#   inflating: images/Recycle Item Image/test/recycle0251_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0252.jpg
#   inflating: images/Recycle Item Image/test/recycle0252_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0254.jpg
#   inflating: images/Recycle Item Image/test/recycle0254_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0255.jpg
#   inflating: images/Recycle Item Image/test/recycle0255_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0258.jpg
#   inflating: images/Recycle Item Image/test/recycle0258_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0259.jpg
#   inflating: images/Recycle Item Image/test/recycle0259_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0260.jpg
#   inflating: images/Recycle Item Image/test/recycle0260_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0261.jpg
#   inflating: images/Recycle Item Image/test/recycle0261_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0262.jpg
#   inflating: images/Recycle Item Image/test/recycle0262_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0263.jpg
#   inflating: images/Recycle Item Image/test/recycle0263_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0264.jpg
#   inflating: images/Recycle Item Image/test/recycle0264_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0265.jpg
#   inflating: images/Recycle Item Image/test/recycle0265_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0268.jpg
#   inflating: images/Recycle Item Image/test/recycle0268_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0269.jpg
#   inflating: images/Recycle Item Image/test/recycle0269_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0270.jpg
#   inflating: images/Recycle Item Image/test/recycle0270_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0271.jpg
#   inflating: images/Recycle Item Image/test/recycle0271_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0272.jpg
#   inflating: images/Recycle Item Image/test/recycle0272_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0273.jpg
#   inflating: images/Recycle Item Image/test/recycle0273_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0274.jpg
#   inflating: images/Recycle Item Image/test/recycle0274_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0275.jpg
#   inflating: images/Recycle Item Image/test/recycle0275_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0277.jpg
#   inflating: images/Recycle Item Image/test/recycle0277_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0278.jpg
#   inflating: images/Recycle Item Image/test/recycle0278_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0280.jpg
#   inflating: images/Recycle Item Image/test/recycle0280_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0282.jpg
#   inflating: images/Recycle Item Image/test/recycle0282_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0284.jpg
#   inflating: images/Recycle Item Image/test/recycle0284_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0285.jpg
#   inflating: images/Recycle Item Image/test/recycle0285_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0287.jpg
#   inflating: images/Recycle Item Image/test/recycle0287_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0288.jpg
#   inflating: images/Recycle Item Image/test/recycle0288_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0289.jpg
#   inflating: images/Recycle Item Image/test/recycle0289_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0292.jpg
#   inflating: images/Recycle Item Image/test/recycle0292_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0293.jpg
#   inflating: images/Recycle Item Image/test/recycle0293_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0294.jpg
#   inflating: images/Recycle Item Image/test/recycle0294_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0296.jpg
#   inflating: images/Recycle Item Image/test/recycle0296_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0297.jpg
#   inflating: images/Recycle Item Image/test/recycle0297_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0298.jpg
#   inflating: images/Recycle Item Image/test/recycle0298_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0299.jpg
#   inflating: images/Recycle Item Image/test/recycle0299_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0300.jpg
#   inflating: images/Recycle Item Image/test/recycle0300_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0301.jpg
#   inflating: images/Recycle Item Image/test/recycle0301_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0302.jpg
#   inflating: images/Recycle Item Image/test/recycle0302_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0304.jpg
#   inflating: images/Recycle Item Image/test/recycle0304_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0306.jpg
#   inflating: images/Recycle Item Image/test/recycle0306_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0307.jpg
#   inflating: images/Recycle Item Image/test/recycle0307_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0308.jpg
#   inflating: images/Recycle Item Image/test/recycle0308_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0310.jpg
#   inflating: images/Recycle Item Image/test/recycle0310_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0311.jpg
#   inflating: images/Recycle Item Image/test/recycle0311_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0312.jpg
#   inflating: images/Recycle Item Image/test/recycle0312_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0313.jpg
#   inflating: images/Recycle Item Image/test/recycle0313_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0314.jpg
#   inflating: images/Recycle Item Image/test/recycle0314_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0315.jpg
#   inflating: images/Recycle Item Image/test/recycle0315_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0316.jpg
#   inflating: images/Recycle Item Image/test/recycle0316_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0317.jpg
#   inflating: images/Recycle Item Image/test/recycle0317_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0319.jpg
#   inflating: images/Recycle Item Image/test/recycle0319_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0321.jpg
#   inflating: images/Recycle Item Image/test/recycle0321_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0322.jpg
#   inflating: images/Recycle Item Image/test/recycle0322_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0325.jpg
#   inflating: images/Recycle Item Image/test/recycle0325_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0326.jpg
#   inflating: images/Recycle Item Image/test/recycle0326_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0328.jpg
#   inflating: images/Recycle Item Image/test/recycle0328_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0329.jpg
#   inflating: images/Recycle Item Image/test/recycle0329_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0333.jpg
#   inflating: images/Recycle Item Image/test/recycle0333_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0335.jpg
#   inflating: images/Recycle Item Image/test/recycle0335_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0336.jpg
#   inflating: images/Recycle Item Image/test/recycle0336_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0339.jpg
#   inflating: images/Recycle Item Image/test/recycle0339_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0341.jpg
#   inflating: images/Recycle Item Image/test/recycle0341_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0342.jpg
#   inflating: images/Recycle Item Image/test/recycle0342_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0343.jpg
#   inflating: images/Recycle Item Image/test/recycle0343_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0344.jpg
#   inflating: images/Recycle Item Image/test/recycle0344_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0345.jpg
#   inflating: images/Recycle Item Image/test/recycle0345_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0346.jpg
#   inflating: images/Recycle Item Image/test/recycle0346_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0347.jpg
#   inflating: images/Recycle Item Image/test/recycle0347_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0349.jpg
#   inflating: images/Recycle Item Image/test/recycle0349_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0350.jpg
#   inflating: images/Recycle Item Image/test/recycle0350_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0351.jpg
#   inflating: images/Recycle Item Image/test/recycle0351_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0353.jpg
#   inflating: images/Recycle Item Image/test/recycle0353_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0354.jpg
#   inflating: images/Recycle Item Image/test/recycle0354_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0355.jpg
#   inflating: images/Recycle Item Image/test/recycle0355_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0356.jpg
#   inflating: images/Recycle Item Image/test/recycle0356_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0357.jpg
#   inflating: images/Recycle Item Image/test/recycle0357_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0358.jpg
#   inflating: images/Recycle Item Image/test/recycle0358_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0360.jpg
#   inflating: images/Recycle Item Image/test/recycle0360_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0361.jpg
#   inflating: images/Recycle Item Image/test/recycle0361_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0363.jpg
#   inflating: images/Recycle Item Image/test/recycle0363_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0366.jpg
#   inflating: images/Recycle Item Image/test/recycle0366_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0368.jpg
#   inflating: images/Recycle Item Image/test/recycle0368_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0369.jpg
#   inflating: images/Recycle Item Image/test/recycle0369_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0370.jpg
#   inflating: images/Recycle Item Image/test/recycle0370_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0371.jpg
#   inflating: images/Recycle Item Image/test/recycle0371_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0374.jpg
#   inflating: images/Recycle Item Image/test/recycle0374_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0375.jpg
#   inflating: images/Recycle Item Image/test/recycle0375_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0376.jpg
#   inflating: images/Recycle Item Image/test/recycle0376_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0377.jpg
#   inflating: images/Recycle Item Image/test/recycle0377_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0378.jpg
#   inflating: images/Recycle Item Image/test/recycle0378_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0379.jpg
#   inflating: images/Recycle Item Image/test/recycle0379_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0380.jpg
#   inflating: images/Recycle Item Image/test/recycle0380_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0381.jpg
#   inflating: images/Recycle Item Image/test/recycle0381_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0382.jpg
#   inflating: images/Recycle Item Image/test/recycle0382_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0385.jpg
#   inflating: images/Recycle Item Image/test/recycle0385_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0391.jpg
#   inflating: images/Recycle Item Image/test/recycle0391_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0393.jpg
#   inflating: images/Recycle Item Image/test/recycle0393_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0394.jpg
#   inflating: images/Recycle Item Image/test/recycle0394_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0398.jpg
#   inflating: images/Recycle Item Image/test/recycle0398_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0400.jpg
#   inflating: images/Recycle Item Image/test/recycle0400_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0403.jpg
#   inflating: images/Recycle Item Image/test/recycle0403_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0404.jpg
#   inflating: images/Recycle Item Image/test/recycle0404_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0405.jpg
#   inflating: images/Recycle Item Image/test/recycle0405_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0406.jpg
#   inflating: images/Recycle Item Image/test/recycle0406=7.jpg
#   inflating: images/Recycle Item Image/test/recycle0406=7_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0406_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0407.jpg
#   inflating: images/Recycle Item Image/test/recycle0408.jpg
#   inflating: images/Recycle Item Image/test/recycle0408_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0410.jpg
#   inflating: images/Recycle Item Image/test/recycle0410_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0411.jpg
#   inflating: images/Recycle Item Image/test/recycle0414.jpg
#   inflating: images/Recycle Item Image/test/recycle0414_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0415.jpg
#   inflating: images/Recycle Item Image/test/recycle0415_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0416.jpg
#   inflating: images/Recycle Item Image/test/recycle0416_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0417.jpg
#   inflating: images/Recycle Item Image/test/recycle0417_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0418.jpg
#   inflating: images/Recycle Item Image/test/recycle0418_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0419.jpg
#   inflating: images/Recycle Item Image/test/recycle0419_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0421.jpg
#   inflating: images/Recycle Item Image/test/recycle0421_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0422.jpg
#   inflating: images/Recycle Item Image/test/recycle0422_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0423.jpg
#   inflating: images/Recycle Item Image/test/recycle0423_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0424.jpg
#   inflating: images/Recycle Item Image/test/recycle0424_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0427.jpg
#   inflating: images/Recycle Item Image/test/recycle0427_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0429.jpg
#   inflating: images/Recycle Item Image/test/recycle0429_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0430.jpg
#   inflating: images/Recycle Item Image/test/recycle0430_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0431.jpg
#   inflating: images/Recycle Item Image/test/recycle0431_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0432.jpg
#   inflating: images/Recycle Item Image/test/recycle0432_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0434.jpg
#   inflating: images/Recycle Item Image/test/recycle0434_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0435.jpg
#   inflating: images/Recycle Item Image/test/recycle0435_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0437.jpg
#   inflating: images/Recycle Item Image/test/recycle0437_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0440.jpg
#   inflating: images/Recycle Item Image/test/recycle0440_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0441.jpg
#   inflating: images/Recycle Item Image/test/recycle0441_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0442.jpg
#   inflating: images/Recycle Item Image/test/recycle0442_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0443.jpg
#   inflating: images/Recycle Item Image/test/recycle0443_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0444.jpg
#   inflating: images/Recycle Item Image/test/recycle0444_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0447.jpg
#   inflating: images/Recycle Item Image/test/recycle0447_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0448.jpg
#   inflating: images/Recycle Item Image/test/recycle0448_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0450.jpg
#   inflating: images/Recycle Item Image/test/recycle0450_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0452.jpg
#   inflating: images/Recycle Item Image/test/recycle0452_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0456.jpg
#   inflating: images/Recycle Item Image/test/recycle0456_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0457.jpg
#   inflating: images/Recycle Item Image/test/recycle0457_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0459.jpg
#   inflating: images/Recycle Item Image/test/recycle0459_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0461.jpg
#   inflating: images/Recycle Item Image/test/recycle0461_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0463.jpg
#   inflating: images/Recycle Item Image/test/recycle0463_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0464.jpg
#   inflating: images/Recycle Item Image/test/recycle0464_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0466.jpg
#   inflating: images/Recycle Item Image/test/recycle0466_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0469.jpg
#   inflating: images/Recycle Item Image/test/recycle0469_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0471.jpg
#   inflating: images/Recycle Item Image/test/recycle0471_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0472.jpg
#   inflating: images/Recycle Item Image/test/recycle0472_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0473.jpg
#   inflating: images/Recycle Item Image/test/recycle0473_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0474.jpg
#   inflating: images/Recycle Item Image/test/recycle0474_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0475.jpg
#   inflating: images/Recycle Item Image/test/recycle0475_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0476.jpg
#   inflating: images/Recycle Item Image/test/recycle0476_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0478.jpg
#   inflating: images/Recycle Item Image/test/recycle0478_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0480.jpg
#   inflating: images/Recycle Item Image/test/recycle0480_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0481.jpg
#   inflating: images/Recycle Item Image/test/recycle0481_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0482.jpg
#   inflating: images/Recycle Item Image/test/recycle0482_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0483.jpg
#   inflating: images/Recycle Item Image/test/recycle0483_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0484.jpg
#   inflating: images/Recycle Item Image/test/recycle0484_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0485.jpg
#   inflating: images/Recycle Item Image/test/recycle0485_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0486.jpg
#   inflating: images/Recycle Item Image/test/recycle0486_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0487.jpg
#   inflating: images/Recycle Item Image/test/recycle0487_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0488.jpg
#   inflating: images/Recycle Item Image/test/recycle0488_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0491.jpg
#   inflating: images/Recycle Item Image/test/recycle0491_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0492.jpg
#   inflating: images/Recycle Item Image/test/recycle0492_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0493.jpg
#   inflating: images/Recycle Item Image/test/recycle0493_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0494.jpg
#   inflating: images/Recycle Item Image/test/recycle0494_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0495.jpg
#   inflating: images/Recycle Item Image/test/recycle0495_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0496.jpg
#   inflating: images/Recycle Item Image/test/recycle0496_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0497.jpg
#   inflating: images/Recycle Item Image/test/recycle0497_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0498.jpg
#   inflating: images/Recycle Item Image/test/recycle0498_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0500.jpg
#   inflating: images/Recycle Item Image/test/recycle0500_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0501.jpg
#   inflating: images/Recycle Item Image/test/recycle0501_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0502.jpg
#   inflating: images/Recycle Item Image/test/recycle0502_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0503.jpg
#   inflating: images/Recycle Item Image/test/recycle0503_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0505.jpg
#   inflating: images/Recycle Item Image/test/recycle0505_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0506.jpg
#   inflating: images/Recycle Item Image/test/recycle0506_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0509.jpg
#   inflating: images/Recycle Item Image/test/recycle0509_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0510.jpg
#   inflating: images/Recycle Item Image/test/recycle0510_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0511.jpg
#   inflating: images/Recycle Item Image/test/recycle0511_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0513.jpg
#   inflating: images/Recycle Item Image/test/recycle0513_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0517.jpg
#   inflating: images/Recycle Item Image/test/recycle0517_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0518.jpg
#   inflating: images/Recycle Item Image/test/recycle0518_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0520.jpg
#   inflating: images/Recycle Item Image/test/recycle0520_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0521.jpg
#   inflating: images/Recycle Item Image/test/recycle0521_jpg.xml
#   inflating: images/Recycle Item Image/test/recycle0522.jpg
#   inflating: images/Recycle Item Image/test/recycle0522_jpg.xml
#    creating: images/Recycle Item Image/train/
#   inflating: images/Recycle Item Image/train/recycle0001.jpg
#   inflating: images/Recycle Item Image/train/recycle00010.jpg
#   inflating: images/Recycle Item Image/train/recycle00010_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0001_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0002.jpg
#   inflating: images/Recycle Item Image/train/recycle0002_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0003.jpg
#   inflating: images/Recycle Item Image/train/recycle0003_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0004.jpg
#   inflating: images/Recycle Item Image/train/recycle0004_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0005.jpg
#   inflating: images/Recycle Item Image/train/recycle0005_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0006.jpg
#   inflating: images/Recycle Item Image/train/recycle0006_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0007.jpg
#   inflating: images/Recycle Item Image/train/recycle0007_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0008.jpg
#   inflating: images/Recycle Item Image/train/recycle0008_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0009.jpg
#   inflating: images/Recycle Item Image/train/recycle0009_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0010.jpg
#   inflating: images/Recycle Item Image/train/recycle0010_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0011.jpg
#   inflating: images/Recycle Item Image/train/recycle0011_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0012.jpg
#   inflating: images/Recycle Item Image/train/recycle0012_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0013.jpg
#   inflating: images/Recycle Item Image/train/recycle0013_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0014.jpg
#   inflating: images/Recycle Item Image/train/recycle0014_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0015.jpg
#   inflating: images/Recycle Item Image/train/recycle0015_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0016.jpg
#   inflating: images/Recycle Item Image/train/recycle0016_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0017.jpg
#   inflating: images/Recycle Item Image/train/recycle0017_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0018.jpg
#   inflating: images/Recycle Item Image/train/recycle0018_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0019.jpg
#   inflating: images/Recycle Item Image/train/recycle0019_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0020.jpg
#   inflating: images/Recycle Item Image/train/recycle0020_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0021.jpg
#   inflating: images/Recycle Item Image/train/recycle0021_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0022.jpg
#   inflating: images/Recycle Item Image/train/recycle0022_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0023.jpg
#   inflating: images/Recycle Item Image/train/recycle0023_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0024.jpg
#   inflating: images/Recycle Item Image/train/recycle0024_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0025.jpg
#   inflating: images/Recycle Item Image/train/recycle0025_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0026.jpg
#   inflating: images/Recycle Item Image/train/recycle0026_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0027.jpg
#   inflating: images/Recycle Item Image/train/recycle0027_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0028.jpg
#   inflating: images/Recycle Item Image/train/recycle0028_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0029.jpg
#   inflating: images/Recycle Item Image/train/recycle0029_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0030.jpg
#   inflating: images/Recycle Item Image/train/recycle0030_jpg.xml
# ...
#   inflating: images/Recycle Item Image/train/recycle0371_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0372.jpg
#   inflating: images/Recycle Item Image/train/recycle0372_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0373.jpg
#   inflating: images/Recycle Item Image/train/recycle0373_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0375.jpg
#   inflating: images/Recycle Item Image/train/recycle0375_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0376.jpg
#   inflating: images/Recycle Item Image/train/recycle0376_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0377.jpg
#   inflating: images/Recycle Item Image/train/recycle0377_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0378.jpg
#   inflating: images/Recycle Item Image/train/recycle0378_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0379.jpg
#   inflating: images/Recycle Item Image/train/recycle0379_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0381.jpg
#   inflating: images/Recycle Item Image/train/recycle0381_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0382.jpg
#   inflating: images/Recycle Item Image/train/recycle0382_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0383.jpg
#   inflating: images/Recycle Item Image/train/recycle0383_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0384.jpg
#   inflating: images/Recycle Item Image/train/recycle0384_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0385.jpg
#   inflating: images/Recycle Item Image/train/recycle0385_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0386.jpg
#   inflating: images/Recycle Item Image/train/recycle0386_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0387.jpg
#   inflating: images/Recycle Item Image/train/recycle0387_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0388.jpg
#   inflating: images/Recycle Item Image/train/recycle0388_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0389.jpg
#   inflating: images/Recycle Item Image/train/recycle0389_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0390.jpg
#   inflating: images/Recycle Item Image/train/recycle0390_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0391.jpg
#   inflating: images/Recycle Item Image/train/recycle0391_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0392.jpg
#   inflating: images/Recycle Item Image/train/recycle0392_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0393.jpg
#   inflating: images/Recycle Item Image/train/recycle0393_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0394.jpg
#   inflating: images/Recycle Item Image/train/recycle0394_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0395.jpg
#   inflating: images/Recycle Item Image/train/recycle0395_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0396.jpg
#   inflating: images/Recycle Item Image/train/recycle0396_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0397.jpg
#   inflating: images/Recycle Item Image/train/recycle0397_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0398.jpg
#   inflating: images/Recycle Item Image/train/recycle0398_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0399.jpg
#   inflating: images/Recycle Item Image/train/recycle0399_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0400.jpg
#   inflating: images/Recycle Item Image/train/recycle0400_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0401.jpg
#   inflating: images/Recycle Item Image/train/recycle0401_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0402.jpg
#   inflating: images/Recycle Item Image/train/recycle0402_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0403.jpg
#   inflating: images/Recycle Item Image/train/recycle0403_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0404.jpg
#   inflating: images/Recycle Item Image/train/recycle0404_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0405.jpg
#   inflating: images/Recycle Item Image/train/recycle0405_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0406.jpg
#   inflating: images/Recycle Item Image/train/recycle0406=7.jpg
#   inflating: images/Recycle Item Image/train/recycle0406=7_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0406_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0408.jpg
#   inflating: images/Recycle Item Image/train/recycle0408_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0409.jpg
#   inflating: images/Recycle Item Image/train/recycle0409_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0410.jpg
#   inflating: images/Recycle Item Image/train/recycle0410_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0412.jpg
#   inflating: images/Recycle Item Image/train/recycle0413.jpg
#   inflating: images/Recycle Item Image/train/recycle0413_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0414.jpg
#   inflating: images/Recycle Item Image/train/recycle0414_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0415.jpg
#   inflating: images/Recycle Item Image/train/recycle0415_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0416.jpg
#   inflating: images/Recycle Item Image/train/recycle0416_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0417.jpg
#   inflating: images/Recycle Item Image/train/recycle0417_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0418.jpg
#   inflating: images/Recycle Item Image/train/recycle0418_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0420.jpg
#   inflating: images/Recycle Item Image/train/recycle0420_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0422.jpg
#   inflating: images/Recycle Item Image/train/recycle0422_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0423.jpg
#   inflating: images/Recycle Item Image/train/recycle0423_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0424.jpg
#   inflating: images/Recycle Item Image/train/recycle0424_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0425.jpg
#   inflating: images/Recycle Item Image/train/recycle0425_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0426.jpg
#   inflating: images/Recycle Item Image/train/recycle0426_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0428.jpg
#   inflating: images/Recycle Item Image/train/recycle0428_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0429.jpg
#   inflating: images/Recycle Item Image/train/recycle0429_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0430.jpg
#   inflating: images/Recycle Item Image/train/recycle0430_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0431.jpg
#   inflating: images/Recycle Item Image/train/recycle0431_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0432.jpg
#   inflating: images/Recycle Item Image/train/recycle0432_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0433.jpg
#   inflating: images/Recycle Item Image/train/recycle0433_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0436.jpg
#   inflating: images/Recycle Item Image/train/recycle0436_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0438.jpg
#   inflating: images/Recycle Item Image/train/recycle0438_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0439.jpg
#   inflating: images/Recycle Item Image/train/recycle0439_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0440.jpg
#   inflating: images/Recycle Item Image/train/recycle0440_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0441.jpg
#   inflating: images/Recycle Item Image/train/recycle0441_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0442.jpg
#   inflating: images/Recycle Item Image/train/recycle0442_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0443.jpg
#   inflating: images/Recycle Item Image/train/recycle0443_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0444.jpg
#   inflating: images/Recycle Item Image/train/recycle0444_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0445.jpg
#   inflating: images/Recycle Item Image/train/recycle0445_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0446.jpg
#   inflating: images/Recycle Item Image/train/recycle0446_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0447.jpg
#   inflating: images/Recycle Item Image/train/recycle0447_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0448.jpg
#   inflating: images/Recycle Item Image/train/recycle0448_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0449.jpg
#   inflating: images/Recycle Item Image/train/recycle0449_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0451.jpg
#   inflating: images/Recycle Item Image/train/recycle0451_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0453.jpg
#   inflating: images/Recycle Item Image/train/recycle0453_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0454.jpg
#   inflating: images/Recycle Item Image/train/recycle0454_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0455.jpg
#   inflating: images/Recycle Item Image/train/recycle0455_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0457.jpg
#   inflating: images/Recycle Item Image/train/recycle0457_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0458.jpg
#   inflating: images/Recycle Item Image/train/recycle0458_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0459.jpg
#   inflating: images/Recycle Item Image/train/recycle0459_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0460.jpg
#   inflating: images/Recycle Item Image/train/recycle0460_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0462.jpg
#   inflating: images/Recycle Item Image/train/recycle0462_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0463.jpg
#   inflating: images/Recycle Item Image/train/recycle0463_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0465.jpg
#   inflating: images/Recycle Item Image/train/recycle0465_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0466.jpg
#   inflating: images/Recycle Item Image/train/recycle0466_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0467.jpg
#   inflating: images/Recycle Item Image/train/recycle0467_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0468.jpg
#   inflating: images/Recycle Item Image/train/recycle0468_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0469.jpg
#   inflating: images/Recycle Item Image/train/recycle0469_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0470.jpg
#   inflating: images/Recycle Item Image/train/recycle0470_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0471.jpg
#   inflating: images/Recycle Item Image/train/recycle0471_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0472.jpg
#   inflating: images/Recycle Item Image/train/recycle0472_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0474.jpg
#   inflating: images/Recycle Item Image/train/recycle0474_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0475.jpg
#   inflating: images/Recycle Item Image/train/recycle0475_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0476.jpg
#   inflating: images/Recycle Item Image/train/recycle0476_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0477.jpg
#   inflating: images/Recycle Item Image/train/recycle0477_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0478.jpg
#   inflating: images/Recycle Item Image/train/recycle0478_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0479.jpg
#   inflating: images/Recycle Item Image/train/recycle0479_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0480.jpg
#   inflating: images/Recycle Item Image/train/recycle0480_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0481.jpg
#   inflating: images/Recycle Item Image/train/recycle0481_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0482.jpg
#   inflating: images/Recycle Item Image/train/recycle0482_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0483.jpg
#   inflating: images/Recycle Item Image/train/recycle0483_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0486.jpg
#   inflating: images/Recycle Item Image/train/recycle0486_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0488.jpg
#   inflating: images/Recycle Item Image/train/recycle0488_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0489.jpg
#   inflating: images/Recycle Item Image/train/recycle0489_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0490.jpg
#   inflating: images/Recycle Item Image/train/recycle0490_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0494.jpg
#   inflating: images/Recycle Item Image/train/recycle0494_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0497.jpg
#   inflating: images/Recycle Item Image/train/recycle0497_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0498.jpg
#   inflating: images/Recycle Item Image/train/recycle0498_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0499.jpg
#   inflating: images/Recycle Item Image/train/recycle0499_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0502.jpg
#   inflating: images/Recycle Item Image/train/recycle0502_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0504.jpg
#   inflating: images/Recycle Item Image/train/recycle0504_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0505.jpg
#   inflating: images/Recycle Item Image/train/recycle0505_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0506.jpg
#   inflating: images/Recycle Item Image/train/recycle0506_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0507.jpg
#   inflating: images/Recycle Item Image/train/recycle0507_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0508.jpg
#   inflating: images/Recycle Item Image/train/recycle0508_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0509.jpg
#   inflating: images/Recycle Item Image/train/recycle0509_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0510.jpg
#   inflating: images/Recycle Item Image/train/recycle0510_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0511.jpg
#   inflating: images/Recycle Item Image/train/recycle0511_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0512.jpg
#   inflating: images/Recycle Item Image/train/recycle0512_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0513.jpg
#   inflating: images/Recycle Item Image/train/recycle0513_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0514.jpg
#   inflating: images/Recycle Item Image/train/recycle0514_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0515.jpg
#   inflating: images/Recycle Item Image/train/recycle0515_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0516.jpg
#   inflating: images/Recycle Item Image/train/recycle0516_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0517.jpg
#   inflating: images/Recycle Item Image/train/recycle0517_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0518.jpg
#   inflating: images/Recycle Item Image/train/recycle0518_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0519.jpg
#   inflating: images/Recycle Item Image/train/recycle0519_jpg.xml
#   inflating: images/Recycle Item Image/train/recycle0521.jpg
#   inflating: images/Recycle Item Image/train/recycle0521_jpg.xml

# %% [markdown]
# Copy the tensorflow train.py example from the legacy folder into the main object detection_folder. This is the file that will handle the training process.

# %%
#copy the tensoflow train.py exmaple from the legacy folder into the main object detection_folder
# !cp /content/tensorflow1/models/research/object_detection/legacy/train.py /content/tensorflow1/models/research/object_detection/

# %% [markdown]
# # Time to Train!

# %% [markdown]
# Train

# %%
# verify that the files indicated in the config file are where you say (test.record and train.record especially)
# Run the training!!!
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=/content/tensorflow1/models/research/object_detection/Recycle-Item-Detection/training/ssd_mobilenet_v2_quantized_300x300_coco.config
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py:125: main (from __main__) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use object_detection/model_main.py.
# WARNING:tensorflow:From /content/tensorflow1/models/research/object_detection/legacy/trainer.py:266: create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.create_global_step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /content/tensorflow1/models/research/object_detection/builders/dataset_builder.py:80: parallel_interleave (from tensorflow.contrib.data.python.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.experimental.parallel_interleave(...)`.
# WARNING:tensorflow:From /content/tensorflow1/models/research/object_detection/legacy/trainer.py:65: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/tensorflow1/models/research/object_detection/core/preprocessor.py:188: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /content/tensorflow1/models/research/object_detection/core/preprocessor.py:1218: calling squeeze (from tensorflow.python.ops.array_ops) with squeeze_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# WARNING:tensorflow:From /content/tensorflow1/models/research/object_detection/core/batcher.py:96: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:753: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:753: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /content/tensorflow1/models/research/object_detection/core/losses.py:664: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/Conv/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_1/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_2/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_3/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_3/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_4/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_4/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_5/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_5/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_6/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_6/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_7/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_7/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_8/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_8/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_9/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_9/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_10/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_10/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_11/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_11/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_12/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_12/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_13/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_14/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_14/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_15/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_15/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_16/expand/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/expanded_conv_16/depthwise/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/Conv_1/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_2_1x1_256/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_2_3x3_s2_512/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_3_1x1_128/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_3_3x3_s2_256/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_4_1x1_128/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_4_3x3_s2_256/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/layer_19_1_Conv2d_5_1x1_64/add_fold
# INFO:tensorflow:Skipping quant after FeatureExtractor/MobilenetV2/layer_19_2_Conv2d_5_3x3_s2_128/add_fold
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/slim/python/slim/learning.py:737: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# 2021-01-29 04:02:56.592669: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-01-29 04:02:56.793582: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-29 04:02:56.794337: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x215f2c00 executing computations on platform CUDA. Devices:
# 2021-01-29 04:02:56.794389: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-01-29 04:02:56.799287: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2021-01-29 04:02:56.799858: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x215f2d60 executing computations on platform Host. Devices:
# 2021-01-29 04:02:56.799893: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2021-01-29 04:02:56.800110: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# totalMemory: 14.73GiB freeMemory: 14.62GiB
# 2021-01-29 04:02:56.800156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2021-01-29 04:02:56.801071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-01-29 04:02:56.801099: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2021-01-29 04:02:56.801110: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2021-01-29 04:02:56.801170: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-01-29 04:02:56.801212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /content/tensorflow1/models/research/object_detection/ssd_mobilenet_v2_quantized_300x300_coco_2019_01_03/model.ckpt
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Starting Session.
# INFO:tensorflow:Saving checkpoint to path training/model.ckpt
# INFO:tensorflow:Starting Queues.
# 2021-01-29 04:03:29.218207: W tensorflow/core/framework/allocator.cc:124] Allocation of 207360000 exceeds 10% of system memory.
# 2021-01-29 04:03:29.338834: W tensorflow/core/framework/allocator.cc:124] Allocation of 207360000 exceeds 10% of system memory.
# INFO:tensorflow:global_step/sec: 0
# 2021-01-29 04:03:51.218474: W tensorflow/core/framework/allocator.cc:124] Allocation of 207360000 exceeds 10% of system memory.
# 2021-01-29 04:03:51.417082: W tensorflow/core/framework/allocator.cc:124] Allocation of 207360000 exceeds 10% of system memory.
# 2021-01-29 04:03:53.055711: W tensorflow/core/framework/allocator.cc:124] Allocation of 127733760 exceeds 10% of system memory.
# INFO:tensorflow:Recording summary at step 0.
# INFO:tensorflow:global step 1: loss = 31.1770 (52.634 sec/step)
# INFO:tensorflow:global step 2: loss = 28.5260 (4.404 sec/step)
# INFO:tensorflow:global step 3: loss = 25.7936 (4.407 sec/step)
# INFO:tensorflow:global step 4: loss = 24.5889 (4.351 sec/step)
# INFO:tensorflow:global step 5: loss = 22.9518 (4.365 sec/step)
# INFO:tensorflow:global step 6: loss = 22.0502 (4.379 sec/step)
# INFO:tensorflow:global step 7: loss = 20.7771 (4.386 sec/step)
# INFO:tensorflow:global step 8: loss = 19.5354 (4.343 sec/step)
# INFO:tensorflow:global step 9: loss = 18.3861 (4.369 sec/step)
# INFO:tensorflow:global step 10: loss = 17.5021 (4.340 sec/step)
# INFO:tensorflow:global step 11: loss = 16.7320 (4.375 sec/step)
# INFO:tensorflow:global step 12: loss = 15.8354 (4.311 sec/step)
# INFO:tensorflow:global step 13: loss = 15.0864 (4.489 sec/step)
# INFO:tensorflow:global step 14: loss = 13.8646 (4.410 sec/step)
# INFO:tensorflow:global step 15: loss = 13.1092 (4.396 sec/step)
# INFO:tensorflow:global step 16: loss = 12.9327 (4.336 sec/step)
# INFO:tensorflow:Recording summary at step 16.
# INFO:tensorflow:global step 17: loss = 12.8482 (7.546 sec/step)
# INFO:tensorflow:global_step/sec: 0.181536
# INFO:tensorflow:global step 18: loss = 11.8335 (4.373 sec/step)
# INFO:tensorflow:global step 19: loss = 11.2214 (4.432 sec/step)
# INFO:tensorflow:global step 20: loss = 11.2939 (4.383 sec/step)
# INFO:tensorflow:global step 21: loss = 10.8061 (4.380 sec/step)
# INFO:tensorflow:global step 22: loss = 10.4622 (4.369 sec/step)
# INFO:tensorflow:global step 23: loss = 10.2433 (4.364 sec/step)
# INFO:tensorflow:global step 24: loss = 10.2590 (4.373 sec/step)
# INFO:tensorflow:global step 25: loss = 9.5733 (4.358 sec/step)
# INFO:tensorflow:global step 26: loss = 9.8969 (4.456 sec/step)
# INFO:tensorflow:global step 27: loss = 9.2940 (4.342 sec/step)
# INFO:tensorflow:global step 28: loss = 9.2073 (4.368 sec/step)
# INFO:tensorflow:global step 29: loss = 9.1035 (4.403 sec/step)
# INFO:tensorflow:global step 30: loss = 8.9653 (4.435 sec/step)
# INFO:tensorflow:global step 31: loss = 9.0215 (4.397 sec/step)
# INFO:tensorflow:global step 32: loss = 9.0477 (4.407 sec/step)
# INFO:tensorflow:global step 33: loss = 8.6818 (4.313 sec/step)
# INFO:tensorflow:global step 34: loss = 8.4199 (4.349 sec/step)
# INFO:tensorflow:global step 35: loss = 8.9284 (4.394 sec/step)
# INFO:tensorflow:global step 36: loss = 8.6698 (4.367 sec/step)
# INFO:tensorflow:global step 37: loss = 8.2918 (4.304 sec/step)
# INFO:tensorflow:global step 38: loss = 8.0025 (4.376 sec/step)
# INFO:tensorflow:global step 39: loss = 8.4590 (4.404 sec/step)
# INFO:tensorflow:global step 40: loss = 8.7896 (4.433 sec/step)
# INFO:tensorflow:global step 41: loss = 7.7626 (4.388 sec/step)
# INFO:tensorflow:global step 42: loss = 8.0287 (4.466 sec/step)
# INFO:tensorflow:global step 43: loss = 8.1038 (4.962 sec/step)
# INFO:tensorflow:Recording summary at step 43.
# INFO:tensorflow:global_step/sec: 0.215748
# INFO:tensorflow:global step 44: loss = 7.9882 (6.697 sec/step)
# INFO:tensorflow:global step 45: loss = 7.6286 (4.404 sec/step)
# INFO:tensorflow:global step 46: loss = 8.1965 (4.394 sec/step)
# INFO:tensorflow:global step 47: loss = 7.4617 (4.404 sec/step)
# INFO:tensorflow:global step 48: loss = 7.6205 (4.362 sec/step)
# INFO:tensorflow:global step 49: loss = 8.1242 (4.375 sec/step)
# INFO:tensorflow:global step 50: loss = 7.5286 (4.408 sec/step)
# INFO:tensorflow:global step 51: loss = 7.3581 (4.369 sec/step)
# INFO:tensorflow:global step 52: loss = 7.4306 (4.390 sec/step)
# INFO:tensorflow:global step 53: loss = 7.5284 (4.341 sec/step)
# INFO:tensorflow:global step 54: loss = 7.7180 (4.409 sec/step)
# INFO:tensorflow:global step 55: loss = 7.2759 (4.389 sec/step)
# INFO:tensorflow:global step 56: loss = 7.1160 (4.356 sec/step)
# INFO:tensorflow:global step 57: loss = 7.3043 (4.425 sec/step)
# INFO:tensorflow:global step 58: loss = 7.5145 (4.392 sec/step)
# INFO:tensorflow:global step 59: loss = 6.8940 (4.367 sec/step)
# INFO:tensorflow:global step 60: loss = 7.2330 (4.378 sec/step)
# INFO:tensorflow:global step 61: loss = 7.2219 (4.313 sec/step)
# INFO:tensorflow:global step 62: loss = 7.5534 (4.376 sec/step)
# INFO:tensorflow:global step 63: loss = 7.9957 (4.363 sec/step)
# INFO:tensorflow:global step 64: loss = 7.4908 (4.360 sec/step)
# INFO:tensorflow:global step 65: loss = 7.1931 (4.367 sec/step)
# INFO:tensorflow:global step 66: loss = 7.4731 (4.406 sec/step)
# INFO:tensorflow:global step 67: loss = 6.7900 (4.368 sec/step)
# INFO:tensorflow:global step 68: loss = 6.8102 (4.447 sec/step)
# INFO:tensorflow:global step 69: loss = 7.5894 (4.385 sec/step)
# INFO:tensorflow:global step 70: loss = 6.8063 (6.490 sec/step)
# INFO:tensorflow:global_step/sec: 0.225941
# INFO:tensorflow:Recording summary at step 70.
# INFO:tensorflow:global step 71: loss = 7.4163 (5.421 sec/step)
# INFO:tensorflow:global step 72: loss = 6.6900 (4.386 sec/step)
# INFO:tensorflow:global step 73: loss = 7.4954 (4.375 sec/step)
# INFO:tensorflow:global step 74: loss = 7.1926 (4.386 sec/step)
# INFO:tensorflow:global step 75: loss = 6.9292 (4.392 sec/step)
# INFO:tensorflow:global step 76: loss = 6.6927 (4.405 sec/step)
# INFO:tensorflow:global step 77: loss = 6.7884 (4.440 sec/step)
# INFO:tensorflow:global step 78: loss = 6.7192 (4.357 sec/step)
# INFO:tensorflow:global step 79: loss = 7.0263 (4.435 sec/step)
# INFO:tensorflow:global step 80: loss = 6.3756 (4.348 sec/step)
# INFO:tensorflow:global step 81: loss = 6.2621 (4.358 sec/step)
# INFO:tensorflow:global step 82: loss = 6.2871 (4.397 sec/step)
# INFO:tensorflow:global step 83: loss = 6.5500 (4.369 sec/step)
# INFO:tensorflow:global step 84: loss = 7.2342 (4.451 sec/step)
# INFO:tensorflow:global step 85: loss = 6.3711 (4.424 sec/step)
# INFO:tensorflow:global step 86: loss = 6.9200 (4.392 sec/step)
# INFO:tensorflow:global step 87: loss = 6.6162 (4.432 sec/step)
# INFO:tensorflow:global step 88: loss = 6.6421 (4.423 sec/step)
# INFO:tensorflow:global step 89: loss = 6.5237 (4.456 sec/step)
# INFO:tensorflow:global step 90: loss = 7.3856 (4.352 sec/step)
# INFO:tensorflow:global step 91: loss = 5.6412 (4.372 sec/step)
# INFO:tensorflow:global step 92: loss = 6.6999 (4.362 sec/step)
# INFO:tensorflow:global step 93: loss = 6.4857 (4.410 sec/step)
# INFO:tensorflow:global step 94: loss = 6.1858 (4.400 sec/step)
# INFO:tensorflow:global step 95: loss = 6.3510 (4.382 sec/step)
# INFO:tensorflow:global step 96: loss = 6.4908 (4.351 sec/step)
# INFO:tensorflow:global step 97: loss = 6.5357 (7.382 sec/step)
# INFO:tensorflow:Recording summary at step 97.
# INFO:tensorflow:global_step/sec: 0.224625
# INFO:tensorflow:global step 98: loss = 6.4745 (4.349 sec/step)
# INFO:tensorflow:global step 99: loss = 5.2189 (4.368 sec/step)
# INFO:tensorflow:global step 100: loss = 6.2285 (4.372 sec/step)
# INFO:tensorflow:global step 101: loss = 6.1742 (4.358 sec/step)
# INFO:tensorflow:global step 102: loss = 6.2531 (4.452 sec/step)
# INFO:tensorflow:global step 103: loss = 6.2685 (4.410 sec/step)
# INFO:tensorflow:global step 104: loss = 6.5116 (4.362 sec/step)
# INFO:tensorflow:global step 105: loss = 6.6195 (4.389 sec/step)
# INFO:tensorflow:global step 106: loss = 6.3917 (4.360 sec/step)
# INFO:tensorflow:global step 107: loss = 6.4645 (4.416 sec/step)
# INFO:tensorflow:global step 108: loss = 5.7259 (4.364 sec/step)
# INFO:tensorflow:global step 109: loss = 6.2187 (4.474 sec/step)
# INFO:tensorflow:global step 110: loss = 5.9385 (4.449 sec/step)
# INFO:tensorflow:global step 111: loss = 5.7957 (4.392 sec/step)
# INFO:tensorflow:global step 112: loss = 5.9806 (4.429 sec/step)
# INFO:tensorflow:global step 113: loss = 6.3970 (4.371 sec/step)
# INFO:tensorflow:global step 114: loss = 6.6097 (4.403 sec/step)
# INFO:tensorflow:global step 115: loss = 6.2334 (4.387 sec/step)
# INFO:tensorflow:global step 116: loss = 6.1374 (4.348 sec/step)
# INFO:tensorflow:global step 117: loss = 5.9244 (4.344 sec/step)
# INFO:tensorflow:global step 118: loss = 5.7272 (4.390 sec/step)
# INFO:tensorflow:global step 119: loss = 6.7541 (4.458 sec/step)
# INFO:tensorflow:global step 120: loss = 5.6264 (4.430 sec/step)
# INFO:tensorflow:global step 121: loss = 5.8011 (4.480 sec/step)
# INFO:tensorflow:global step 122: loss = 6.4103 (4.405 sec/step)
# INFO:tensorflow:Saving checkpoint to path training/model.ckpt
# INFO:tensorflow:global step 123: loss = 5.3067 (7.707 sec/step)
# INFO:tensorflow:global_step/sec: 0.217056
# INFO:tensorflow:Recording summary at step 123.
# INFO:tensorflow:global step 124: loss = 5.8546 (6.045 sec/step)
# INFO:tensorflow:global step 125: loss = 5.9669 (4.415 sec/step)
# INFO:tensorflow:global step 126: loss = 6.5987 (4.430 sec/step)
# INFO:tensorflow:global step 127: loss = 6.0455 (4.446 sec/step)
# INFO:tensorflow:global step 128: loss = 6.3993 (4.385 sec/step)
# INFO:tensorflow:global step 129: loss = 6.0168 (4.349 sec/step)
# INFO:tensorflow:global step 130: loss = 6.2347 (4.395 sec/step)
# INFO:tensorflow:global step 131: loss = 5.4553 (4.377 sec/step)
# INFO:tensorflow:global step 132: loss = 5.2622 (4.426 sec/step)
# INFO:tensorflow:global step 133: loss = 5.3785 (4.380 sec/step)
# INFO:tensorflow:global step 134: loss = 6.2920 (4.350 sec/step)
# INFO:tensorflow:global step 135: loss = 6.0021 (4.372 sec/step)
# INFO:tensorflow:global step 136: loss = 6.2391 (4.365 sec/step)
# INFO:tensorflow:global step 137: loss = 5.9604 (4.431 sec/step)
# INFO:tensorflow:global step 138: loss = 5.3847 (4.409 sec/step)
# INFO:tensorflow:global step 139: loss = 6.5465 (4.438 sec/step)
# INFO:tensorflow:global step 140: loss = 6.0693 (4.427 sec/step)
# INFO:tensorflow:global step 141: loss = 5.8055 (4.375 sec/step)
# INFO:tensorflow:global step 142: loss = 5.7088 (4.445 sec/step)
# INFO:tensorflow:global step 143: loss = 5.8622 (4.416 sec/step)
# INFO:tensorflow:global step 144: loss = 5.6960 (4.395 sec/step)
# INFO:tensorflow:global step 145: loss = 5.5145 (4.327 sec/step)
# INFO:tensorflow:global step 146: loss = 4.6903 (4.444 sec/step)
# INFO:tensorflow:global step 147: loss = 5.7759 (4.371 sec/step)
# INFO:tensorflow:global step 148: loss = 6.4664 (4.366 sec/step)
# INFO:tensorflow:global step 149: loss = 5.8088 (5.247 sec/step)
# INFO:tensorflow:Recording summary at step 149.
# INFO:tensorflow:global_step/sec: 0.215825
# INFO:tensorflow:global step 150: loss = 5.7486 (6.632 sec/step)
# INFO:tensorflow:global step 151: loss = 5.7702 (4.374 sec/step)
# INFO:tensorflow:global step 152: loss = 5.9574 (4.393 sec/step)
# INFO:tensorflow:global step 153: loss = 5.5664 (4.408 sec/step)
# INFO:tensorflow:global step 154: loss = 5.4175 (4.461 sec/step)
# INFO:tensorflow:global step 155: loss = 5.6428 (4.449 sec/step)
# INFO:tensorflow:global step 156: loss = 5.8848 (4.423 sec/step)
# INFO:tensorflow:global step 157: loss = 5.3716 (4.391 sec/step)
# INFO:tensorflow:global step 158: loss = 5.5585 (4.404 sec/step)
# INFO:tensorflow:global step 159: loss = 5.5606 (4.406 sec/step)
# INFO:tensorflow:global step 160: loss = 5.6076 (4.395 sec/step)
# INFO:tensorflow:global step 161: loss = 5.4881 (4.311 sec/step)
# INFO:tensorflow:global step 162: loss = 5.7532 (4.419 sec/step)
# INFO:tensorflow:global step 163: loss = 5.1223 (4.436 sec/step)
# INFO:tensorflow:global step 164: loss = 6.0457 (4.360 sec/step)
# INFO:tensorflow:global step 165: loss = 5.4752 (4.345 sec/step)
# INFO:tensorflow:global step 166: loss = 5.5530 (4.376 sec/step)
# INFO:tensorflow:global step 167: loss = 5.1785 (4.409 sec/step)
# INFO:tensorflow:global step 168: loss = 5.5719 (4.345 sec/step)
# INFO:tensorflow:global step 169: loss = 5.6738 (4.375 sec/step)
# INFO:tensorflow:global step 170: loss = 5.4599 (4.412 sec/step)
# INFO:tensorflow:global step 171: loss = 5.8366 (4.331 sec/step)
# INFO:tensorflow:global step 172: loss = 5.8037 (4.432 sec/step)
# INFO:tensorflow:global step 173: loss = 5.4975 (4.413 sec/step)
# INFO:tensorflow:global step 174: loss = 5.4374 (4.476 sec/step)
# INFO:tensorflow:global step 175: loss = 5.3497 (4.410 sec/step)
# INFO:tensorflow:global step 176: loss = 5.2484 (6.612 sec/step)
# INFO:tensorflow:global_step/sec: 0.225783
# INFO:tensorflow:Recording summary at step 176.
# INFO:tensorflow:global step 177: loss = 5.7985 (5.363 sec/step)
# INFO:tensorflow:global step 178: loss = 5.5113 (4.446 sec/step)
# INFO:tensorflow:global step 179: loss = 5.0486 (4.444 sec/step)
# INFO:tensorflow:global step 180: loss = 5.0687 (4.350 sec/step)
# INFO:tensorflow:global step 181: loss = 5.9277 (4.424 sec/step)
# INFO:tensorflow:global step 182: loss = 5.2470 (4.352 sec/step)
# INFO:tensorflow:global step 183: loss = 5.8256 (4.330 sec/step)
# INFO:tensorflow:global step 184: loss = 5.8436 (4.362 sec/step)
# INFO:tensorflow:global step 185: loss = 5.4391 (4.354 sec/step)
# INFO:tensorflow:global step 186: loss = 4.8972 (4.437 sec/step)
# INFO:tensorflow:global step 187: loss = 5.8885 (4.418 sec/step)
# INFO:tensorflow:global step 188: loss = 6.2617 (4.399 sec/step)
# INFO:tensorflow:global step 189: loss = 4.8373 (4.380 sec/step)
# INFO:tensorflow:global step 190: loss = 5.0274 (4.445 sec/step)
# INFO:tensorflow:global step 191: loss = 5.3613 (4.414 sec/step)
# INFO:tensorflow:global step 192: loss = 4.9787 (4.424 sec/step)
# INFO:tensorflow:global step 193: loss = 4.5428 (4.398 sec/step)
# INFO:tensorflow:global step 194: loss = 5.6884 (4.365 sec/step)
# INFO:tensorflow:global step 195: loss = 5.1686 (4.449 sec/step)
# INFO:tensorflow:global step 196: loss = 5.9817 (4.385 sec/step)
# INFO:tensorflow:global step 197: loss = 5.1573 (4.388 sec/step)
# INFO:tensorflow:global step 198: loss = 5.0089 (4.356 sec/step)
# INFO:tensorflow:global step 199: loss = 5.2420 (4.364 sec/step)
# INFO:tensorflow:global step 200: loss = 4.6844 (4.413 sec/step)
# INFO:tensorflow:global step 201: loss = 5.4336 (4.381 sec/step)
# INFO:tensorflow:global step 202: loss = 5.5828 (4.678 sec/step)
# INFO:tensorflow:Recording summary at step 202.
# INFO:tensorflow:global_step/sec: 0.216754
# INFO:tensorflow:global step 203: loss = 5.2772 (7.136 sec/step)
# INFO:tensorflow:global step 204: loss = 5.5599 (4.368 sec/step)
# INFO:tensorflow:global step 205: loss = 5.4929 (4.384 sec/step)
# INFO:tensorflow:global step 206: loss = 5.5197 (4.349 sec/step)
# INFO:tensorflow:global step 207: loss = 4.9277 (4.337 sec/step)
# INFO:tensorflow:global step 208: loss = 4.5548 (4.371 sec/step)
# INFO:tensorflow:global step 209: loss = 4.6101 (4.446 sec/step)
# INFO:tensorflow:global step 210: loss = 4.6272 (4.409 sec/step)
# INFO:tensorflow:global step 211: loss = 4.7077 (4.384 sec/step)
# INFO:tensorflow:global step 212: loss = 6.1936 (4.407 sec/step)
# INFO:tensorflow:global step 213: loss = 5.4053 (4.414 sec/step)
# INFO:tensorflow:global step 214: loss = 5.4435 (4.425 sec/step)
# INFO:tensorflow:global step 215: loss = 5.4535 (4.383 sec/step)
# INFO:tensorflow:global step 216: loss = 5.1259 (4.417 sec/step)
# INFO:tensorflow:global step 217: loss = 4.9805 (4.295 sec/step)
# INFO:tensorflow:global step 218: loss = 5.0691 (4.381 sec/step)
# INFO:tensorflow:global step 219: loss = 5.1963 (4.425 sec/step)
# INFO:tensorflow:global step 220: loss = 4.8310 (4.357 sec/step)
# INFO:tensorflow:global step 221: loss = 5.1514 (4.368 sec/step)
# INFO:tensorflow:global step 222: loss = 5.2407 (4.424 sec/step)
# INFO:tensorflow:global step 223: loss = 5.0471 (4.442 sec/step)
# INFO:tensorflow:global step 224: loss = 5.6236 (4.349 sec/step)
# INFO:tensorflow:global step 225: loss = 5.0702 (4.392 sec/step)
# INFO:tensorflow:global step 226: loss = 4.7423 (4.374 sec/step)
# INFO:tensorflow:global step 227: loss = 4.9073 (4.412 sec/step)
# INFO:tensorflow:global step 228: loss = 4.8791 (4.418 sec/step)
# INFO:tensorflow:global step 229: loss = 5.1025 (5.999 sec/step)
# INFO:tensorflow:global_step/sec: 0.224825
# INFO:tensorflow:Recording summary at step 229.
# INFO:tensorflow:global step 230: loss = 5.4445 (6.015 sec/step)
# INFO:tensorflow:global step 231: loss = 5.4315 (4.360 sec/step)
# INFO:tensorflow:global step 232: loss = 5.2314 (4.385 sec/step)
# INFO:tensorflow:global step 233: loss = 4.6312 (4.360 sec/step)
# INFO:tensorflow:global step 234: loss = 4.9883 (4.358 sec/step)
# INFO:tensorflow:global step 235: loss = 5.1910 (4.352 sec/step)
# INFO:tensorflow:global step 236: loss = 4.7864 (4.374 sec/step)
# INFO:tensorflow:global step 237: loss = 4.7233 (4.362 sec/step)
# INFO:tensorflow:global step 238: loss = 4.6194 (4.328 sec/step)
# INFO:tensorflow:global step 239: loss = 4.4451 (4.383 sec/step)
# INFO:tensorflow:global step 240: loss = 5.7713 (4.381 sec/step)
# INFO:tensorflow:global step 241: loss = 5.4425 (4.409 sec/step)
# INFO:tensorflow:global step 242: loss = 4.4846 (4.406 sec/step)
# INFO:tensorflow:global step 243: loss = 5.6029 (4.366 sec/step)
# INFO:tensorflow:global step 244: loss = 4.7654 (4.425 sec/step)
# INFO:tensorflow:global step 245: loss = 4.8106 (4.391 sec/step)
# INFO:tensorflow:global step 246: loss = 3.9936 (4.515 sec/step)
# INFO:tensorflow:global step 247: loss = 5.2207 (4.448 sec/step)
# INFO:tensorflow:global step 248: loss = 4.2465 (4.451 sec/step)
# INFO:tensorflow:global step 249: loss = 4.4153 (4.420 sec/step)
# INFO:tensorflow:global step 250: loss = 5.0937 (4.391 sec/step)
# INFO:tensorflow:global step 251: loss = 4.3426 (4.415 sec/step)
# INFO:tensorflow:global step 252: loss = 5.4393 (4.368 sec/step)
# INFO:tensorflow:global step 253: loss = 4.3832 (4.347 sec/step)
# INFO:tensorflow:global step 254: loss = 4.4681 (4.358 sec/step)
# INFO:tensorflow:global step 255: loss = 4.0915 (4.365 sec/step)
# INFO:tensorflow:Saving checkpoint to path training/model.ckpt
# INFO:tensorflow:global step 256: loss = 5.0651 (8.496 sec/step)
# INFO:tensorflow:Recording summary at step 256.
# INFO:tensorflow:global step 257: loss = 4.3989 (5.247 sec/step)
# INFO:tensorflow:global step 258: loss = 5.6358 (4.357 sec/step)
# INFO:tensorflow:global step 259: loss = 4.7214 (4.355 sec/step)
# INFO:tensorflow:global step 260: loss = 5.5203 (4.368 sec/step)
# INFO:tensorflow:global step 261: loss = 4.6850 (4.341 sec/step)
# INFO:tensorflow:global step 262: loss = 4.9620 (4.448 sec/step)
# INFO:tensorflow:global step 263: loss = 5.4187 (4.438 sec/step)
# INFO:tensorflow:global step 264: loss = 4.3245 (4.400 sec/step)
# INFO:tensorflow:global step 265: loss = 4.4121 (4.422 sec/step)
# INFO:tensorflow:global step 266: loss = 4.7060 (4.421 sec/step)
# INFO:tensorflow:global step 267: loss = 4.3129 (4.376 sec/step)
# INFO:tensorflow:global step 268: loss = 5.3642 (4.407 sec/step)
# INFO:tensorflow:global step 269: loss = 4.8035 (4.489 sec/step)
# INFO:tensorflow:global step 270: loss = 4.6465 (4.377 sec/step)
# INFO:tensorflow:global step 271: loss = 5.4890 (4.456 sec/step)
# INFO:tensorflow:global step 272: loss = 5.0153 (4.442 sec/step)
# INFO:tensorflow:global step 273: loss = 4.7944 (4.445 sec/step)
# INFO:tensorflow:global step 274: loss = 4.4178 (4.340 sec/step)
# INFO:tensorflow:global step 275: loss = 4.6473 (4.370 sec/step)
# INFO:tensorflow:global step 276: loss = 4.4815 (4.430 sec/step)
# INFO:tensorflow:global step 277: loss = 4.9625 (4.455 sec/step)
# INFO:tensorflow:global step 278: loss = 4.7704 (4.580 sec/step)
# INFO:tensorflow:global step 279: loss = 4.3017 (4.520 sec/step)
# INFO:tensorflow:global step 280: loss = 4.8801 (4.485 sec/step)
# INFO:tensorflow:global step 281: loss = 4.1173 (4.426 sec/step)
# INFO:tensorflow:global step 282: loss = 5.0479 (6.902 sec/step)
# INFO:tensorflow:Recording summary at step 282.
# INFO:tensorflow:global step 283: loss = 4.7417 (5.258 sec/step)
# INFO:tensorflow:global step 284: loss = 4.7656 (4.499 sec/step)
# INFO:tensorflow:global step 285: loss = 5.1540 (4.410 sec/step)
# INFO:tensorflow:global step 286: loss = 4.8167 (4.454 sec/step)
# INFO:tensorflow:global step 287: loss = 4.3481 (4.441 sec/step)
# INFO:tensorflow:global step 288: loss = 4.5992 (4.390 sec/step)
# INFO:tensorflow:global step 289: loss = 4.7623 (4.511 sec/step)
# INFO:tensorflow:global step 290: loss = 5.2742 (4.420 sec/step)
# INFO:tensorflow:global step 291: loss = 4.1631 (4.430 sec/step)
# INFO:tensorflow:global step 292: loss = 4.5093 (4.444 sec/step)
# INFO:tensorflow:global step 293: loss = 4.8217 (4.400 sec/step)
# INFO:tensorflow:global step 294: loss = 4.5897 (4.427 sec/step)
# INFO:tensorflow:global step 295: loss = 4.3004 (4.417 sec/step)
# INFO:tensorflow:global step 296: loss = 4.8782 (4.413 sec/step)
# INFO:tensorflow:global step 297: loss = 4.6640 (4.440 sec/step)
# INFO:tensorflow:global step 298: loss = 4.3122 (4.451 sec/step)
# INFO:tensorflow:global step 299: loss = 4.6581 (4.424 sec/step)
# INFO:tensorflow:global step 300: loss = 4.3532 (4.380 sec/step)
# INFO:tensorflow:global step 301: loss = 4.5017 (4.377 sec/step)
# INFO:tensorflow:global step 302: loss = 5.0706 (4.385 sec/step)
# INFO:tensorflow:global step 303: loss = 4.7932 (4.399 sec/step)
# INFO:tensorflow:global step 304: loss = 4.4844 (4.327 sec/step)
# INFO:tensorflow:global step 305: loss = 4.5118 (4.399 sec/step)
# INFO:tensorflow:global step 306: loss = 4.7128 (4.359 sec/step)
# INFO:tensorflow:global step 307: loss = 4.2200 (4.399 sec/step)
# INFO:tensorflow:global step 308: loss = 4.9395 (5.953 sec/step)
# INFO:tensorflow:Recording summary at step 308.
# INFO:tensorflow:global step 309: loss = 4.0898 (5.979 sec/step)
# INFO:tensorflow:global step 310: loss = 4.8921 (4.412 sec/step)
# INFO:tensorflow:global step 311: loss = 5.0126 (4.426 sec/step)
# INFO:tensorflow:global step 312: loss = 4.9439 (4.428 sec/step)
# INFO:tensorflow:global step 313: loss = 4.9072 (4.393 sec/step)
# INFO:tensorflow:global step 314: loss = 4.4814 (4.474 sec/step)
# INFO:tensorflow:global step 315: loss = 4.8593 (4.464 sec/step)
# INFO:tensorflow:global step 316: loss = 4.5721 (4.401 sec/step)
# INFO:tensorflow:global step 317: loss = 5.0135 (4.444 sec/step)
# INFO:tensorflow:global step 318: loss = 4.4682 (4.414 sec/step)
# INFO:tensorflow:global step 319: loss = 5.3238 (4.423 sec/step)
# INFO:tensorflow:global step 320: loss = 4.7092 (4.334 sec/step)
# INFO:tensorflow:global step 321: loss = 4.5322 (4.451 sec/step)
# INFO:tensorflow:global step 322: loss = 4.6120 (4.435 sec/step)
# INFO:tensorflow:global step 323: loss = 4.5681 (4.428 sec/step)
# INFO:tensorflow:global step 324: loss = 5.1327 (4.387 sec/step)
# INFO:tensorflow:global step 325: loss = 5.2370 (4.419 sec/step)
# INFO:tensorflow:global step 326: loss = 4.3880 (4.388 sec/step)
# INFO:tensorflow:global step 327: loss = 4.6165 (4.420 sec/step)
# INFO:tensorflow:global step 328: loss = 4.8650 (4.425 sec/step)
# INFO:tensorflow:global step 329: loss = 4.4453 (4.383 sec/step)
# INFO:tensorflow:global step 330: loss = 4.7521 (4.471 sec/step)
# INFO:tensorflow:global step 331: loss = 4.5983 (4.396 sec/step)
# INFO:tensorflow:global step 332: loss = 4.4144 (4.402 sec/step)
# INFO:tensorflow:global step 333: loss = 4.2294 (4.432 sec/step)
# INFO:tensorflow:global step 334: loss = 4.4207 (4.447 sec/step)
# INFO:tensorflow:Recording summary at step 334.
# INFO:tensorflow:global step 335: loss = 3.9151 (7.579 sec/step)
# INFO:tensorflow:global step 336: loss = 4.8917 (4.360 sec/step)
# INFO:tensorflow:global step 337: loss = 4.1066 (4.364 sec/step)
# INFO:tensorflow:global step 338: loss = 4.2867 (4.412 sec/step)
# INFO:tensorflow:global step 339: loss = 4.5625 (4.423 sec/step)
# INFO:tensorflow:global step 340: loss = 3.8591 (4.371 sec/step)
# INFO:tensorflow:global step 341: loss = 4.7829 (4.458 sec/step)
# INFO:tensorflow:global step 342: loss = 4.0344 (4.377 sec/step)
# INFO:tensorflow:global step 343: loss = 4.6177 (4.368 sec/step)
# INFO:tensorflow:global step 344: loss = 4.2356 (4.365 sec/step)
# INFO:tensorflow:global step 345: loss = 4.7257 (4.391 sec/step)
# INFO:tensorflow:global step 346: loss = 4.6999 (4.428 sec/step)
# INFO:tensorflow:global step 347: loss = 4.0341 (4.404 sec/step)
# INFO:tensorflow:global step 348: loss = 4.2932 (4.492 sec/step)
# INFO:tensorflow:global step 349: loss = 4.1335 (4.445 sec/step)
# INFO:tensorflow:global step 350: loss = 4.5405 (4.414 sec/step)
# INFO:tensorflow:global step 351: loss = 4.3961 (4.464 sec/step)
# INFO:tensorflow:global step 352: loss = 4.9518 (4.492 sec/step)
# INFO:tensorflow:global step 353: loss = 4.2698 (4.406 sec/step)
# INFO:tensorflow:global step 354: loss = 5.0453 (4.393 sec/step)
# INFO:tensorflow:global step 355: loss = 4.4296 (4.457 sec/step)
# INFO:tensorflow:global step 356: loss = 4.8043 (4.484 sec/step)
# INFO:tensorflow:global step 357: loss = 4.5625 (4.523 sec/step)
# INFO:tensorflow:global step 358: loss = 4.6227 (4.466 sec/step)
# INFO:tensorflow:global step 359: loss = 4.4038 (4.430 sec/step)
# INFO:tensorflow:global step 360: loss = 4.2123 (4.425 sec/step)
# INFO:tensorflow:global step 361: loss = 4.4416 (6.560 sec/step)
# INFO:tensorflow:Recording summary at step 361.
# INFO:tensorflow:global step 362: loss = 4.2134 (5.501 sec/step)
# INFO:tensorflow:global step 363: loss = 4.3614 (4.427 sec/step)
# INFO:tensorflow:global step 364: loss = 4.5038 (4.416 sec/step)
# INFO:tensorflow:global step 365: loss = 3.8612 (4.410 sec/step)
# INFO:tensorflow:global step 366: loss = 4.9328 (4.472 sec/step)
# INFO:tensorflow:global step 367: loss = 4.4054 (4.418 sec/step)
# INFO:tensorflow:global step 368: loss = 4.8104 (4.448 sec/step)
# INFO:tensorflow:global step 369: loss = 4.6815 (4.440 sec/step)
# INFO:tensorflow:global step 370: loss = 4.3759 (4.404 sec/step)
# INFO:tensorflow:global step 371: loss = 4.5002 (4.397 sec/step)
# INFO:tensorflow:global step 372: loss = 4.3498 (4.377 sec/step)
# INFO:tensorflow:global step 373: loss = 3.8775 (4.440 sec/step)
# INFO:tensorflow:global step 374: loss = 4.4995 (4.368 sec/step)
# INFO:tensorflow:global step 375: loss = 4.3659 (4.388 sec/step)
# INFO:tensorflow:global step 376: loss = 4.3299 (4.388 sec/step)
# INFO:tensorflow:global step 377: loss = 3.5222 (4.370 sec/step)
# INFO:tensorflow:global step 378: loss = 4.6684 (4.416 sec/step)
# INFO:tensorflow:global step 379: loss = 4.6681 (4.409 sec/step)
# INFO:tensorflow:global step 380: loss = 4.6694 (4.373 sec/step)
# INFO:tensorflow:global step 381: loss = 4.0770 (4.372 sec/step)
# INFO:tensorflow:global step 382: loss = 4.5051 (4.458 sec/step)
# INFO:tensorflow:global step 383: loss = 4.1154 (4.440 sec/step)
# INFO:tensorflow:global step 384: loss = 3.5549 (4.458 sec/step)
# INFO:tensorflow:global step 385: loss = 4.4020 (4.468 sec/step)
# INFO:tensorflow:global step 386: loss = 4.3039 (4.484 sec/step)
# INFO:tensorflow:Saving checkpoint to path training/model.ckpt
# INFO:tensorflow:global step 387: loss = 4.3860 (5.274 sec/step)
# INFO:tensorflow:Recording summary at step 387.
# INFO:tensorflow:global step 388: loss = 4.5036 (8.343 sec/step)
# INFO:tensorflow:global step 389: loss = 5.3410 (4.402 sec/step)
# INFO:tensorflow:global step 390: loss = 4.5981 (4.430 sec/step)
# INFO:tensorflow:global step 391: loss = 3.7222 (4.440 sec/step)
# INFO:tensorflow:global step 392: loss = 4.3299 (4.452 sec/step)
# INFO:tensorflow:global step 393: loss = 4.0763 (4.474 sec/step)
# INFO:tensorflow:global step 394: loss = 4.3784 (4.464 sec/step)
# INFO:tensorflow:global step 395: loss = 4.7419 (4.352 sec/step)
# INFO:tensorflow:global step 396: loss = 4.2752 (4.446 sec/step)
# INFO:tensorflow:global step 397: loss = 4.1881 (4.424 sec/step)
# INFO:tensorflow:global step 398: loss = 4.3964 (4.424 sec/step)
# INFO:tensorflow:global step 399: loss = 3.5588 (4.414 sec/step)
# INFO:tensorflow:global step 400: loss = 3.9591 (4.416 sec/step)
# INFO:tensorflow:global step 401: loss = 4.4122 (4.429 sec/step)
# INFO:tensorflow:global step 402: loss = 4.0059 (4.456 sec/step)
# INFO:tensorflow:global step 403: loss = 3.5841 (4.370 sec/step)
# INFO:tensorflow:global step 404: loss = 4.8700 (4.392 sec/step)
# INFO:tensorflow:global step 405: loss = 4.2600 (4.415 sec/step)
# INFO:tensorflow:global step 406: loss = 4.8144 (4.423 sec/step)
# INFO:tensorflow:global step 407: loss = 4.2221 (4.432 sec/step)
# INFO:tensorflow:global step 408: loss = 4.0673 (4.379 sec/step)
# INFO:tensorflow:global step 409: loss = 3.8797 (4.352 sec/step)
# INFO:tensorflow:global step 410: loss = 4.7729 (4.479 sec/step)
# INFO:tensorflow:global step 411: loss = 4.4795 (4.399 sec/step)
# INFO:tensorflow:global step 412: loss = 3.8171 (4.372 sec/step)
# INFO:tensorflow:global step 413: loss = 4.3484 (4.665 sec/step)
# INFO:tensorflow:Recording summary at step 413.
# INFO:tensorflow:global step 414: loss = 4.3967 (7.127 sec/step)
# INFO:tensorflow:global step 415: loss = 3.9197 (4.411 sec/step)
# INFO:tensorflow:global step 416: loss = 4.5283 (4.413 sec/step)
# INFO:tensorflow:global step 417: loss = 4.4099 (4.448 sec/step)
# INFO:tensorflow:global step 418: loss = 4.5951 (4.389 sec/step)
# INFO:tensorflow:global step 419: loss = 4.3122 (4.400 sec/step)
# INFO:tensorflow:global step 420: loss = 3.8104 (4.390 sec/step)
# INFO:tensorflow:global step 421: loss = 4.7790 (4.428 sec/step)
# INFO:tensorflow:global step 422: loss = 4.1792 (4.428 sec/step)
# INFO:tensorflow:global step 423: loss = 4.9004 (4.489 sec/step)
# INFO:tensorflow:global step 424: loss = 3.9237 (4.411 sec/step)
# INFO:tensorflow:global step 425: loss = 4.1576 (4.393 sec/step)
# INFO:tensorflow:global step 426: loss = 4.1124 (4.383 sec/step)
# INFO:tensorflow:global step 427: loss = 4.8547 (4.382 sec/step)
# INFO:tensorflow:global step 428: loss = 4.6089 (4.398 sec/step)
# INFO:tensorflow:global step 429: loss = 3.9059 (4.405 sec/step)
# INFO:tensorflow:global step 430: loss = 4.0785 (4.383 sec/step)
# INFO:tensorflow:global step 431: loss = 4.4438 (4.405 sec/step)
# INFO:tensorflow:global step 432: loss = 3.2510 (4.384 sec/step)
# INFO:tensorflow:global step 433: loss = 4.4340 (4.438 sec/step)
# INFO:tensorflow:global step 434: loss = 3.9134 (4.441 sec/step)
# INFO:tensorflow:global step 435: loss = 4.0606 (4.410 sec/step)
# INFO:tensorflow:global step 436: loss = 4.1342 (4.359 sec/step)
# INFO:tensorflow:global step 437: loss = 4.3977 (4.400 sec/step)
# INFO:tensorflow:global step 438: loss = 4.1823 (4.370 sec/step)
# INFO:tensorflow:global step 439: loss = 3.7273 (4.383 sec/step)
# INFO:tensorflow:global step 440: loss = 4.1509 (6.598 sec/step)
# INFO:tensorflow:Recording summary at step 440.
# INFO:tensorflow:global step 441: loss = 5.5395 (5.430 sec/step)
# INFO:tensorflow:global step 442: loss = 4.3763 (4.413 sec/step)
# INFO:tensorflow:global step 443: loss = 4.1292 (4.420 sec/step)
# INFO:tensorflow:global step 444: loss = 4.6421 (4.395 sec/step)
# INFO:tensorflow:global step 445: loss = 4.1407 (4.418 sec/step)
# INFO:tensorflow:global step 446: loss = 4.3482 (4.369 sec/step)
# INFO:tensorflow:global step 447: loss = 4.2854 (4.401 sec/step)
# INFO:tensorflow:global step 448: loss = 3.9767 (4.348 sec/step)
# INFO:tensorflow:global step 449: loss = 4.7876 (4.406 sec/step)
# INFO:tensorflow:global step 450: loss = 3.7301 (4.463 sec/step)
# INFO:tensorflow:global step 451: loss = 4.5900 (4.439 sec/step)
# INFO:tensorflow:global step 452: loss = 4.4072 (4.448 sec/step)
# INFO:tensorflow:global step 453: loss = 4.1692 (4.415 sec/step)
# INFO:tensorflow:global step 454: loss = 3.9090 (4.428 sec/step)
# INFO:tensorflow:global step 455: loss = 4.3491 (4.390 sec/step)
# INFO:tensorflow:global step 456: loss = 4.4214 (4.435 sec/step)
# INFO:tensorflow:global step 457: loss = 4.3006 (4.429 sec/step)
# INFO:tensorflow:global step 458: loss = 4.2994 (4.430 sec/step)
# INFO:tensorflow:global step 459: loss = 4.0760 (4.411 sec/step)
# INFO:tensorflow:global step 460: loss = 4.6006 (4.370 sec/step)
# INFO:tensorflow:global step 461: loss = 3.9855 (4.361 sec/step)
# INFO:tensorflow:global step 462: loss = 4.5918 (4.333 sec/step)
# INFO:tensorflow:global step 463: loss = 4.2816 (4.399 sec/step)
# INFO:tensorflow:global step 464: loss = 3.6683 (4.419 sec/step)
# INFO:tensorflow:global step 465: loss = 3.4732 (4.370 sec/step)
# INFO:tensorflow:global step 466: loss = 3.9442 (4.695 sec/step)
# INFO:tensorflow:global step 467: loss = 4.5178 (7.014 sec/step)
# INFO:tensorflow:Recording summary at step 467.
# INFO:tensorflow:global step 468: loss = 4.4214 (4.397 sec/step)
# INFO:tensorflow:global step 469: loss = 3.9809 (4.395 sec/step)
# INFO:tensorflow:global step 470: loss = 3.9988 (4.358 sec/step)
# INFO:tensorflow:global step 471: loss = 3.9561 (4.386 sec/step)
# INFO:tensorflow:global step 472: loss = 3.9455 (4.384 sec/step)
# INFO:tensorflow:global step 473: loss = 3.8140 (4.402 sec/step)
# INFO:tensorflow:global step 474: loss = 4.5444 (4.429 sec/step)
# INFO:tensorflow:global step 475: loss = 4.2186 (4.446 sec/step)
# INFO:tensorflow:global step 476: loss = 5.1892 (4.395 sec/step)
# INFO:tensorflow:global step 477: loss = 3.3313 (4.390 sec/step)
# INFO:tensorflow:global step 478: loss = 4.9177 (4.430 sec/step)
# INFO:tensorflow:global step 479: loss = 3.5208 (4.375 sec/step)
# INFO:tensorflow:global step 480: loss = 4.2393 (4.446 sec/step)
# INFO:tensorflow:global step 481: loss = 4.3711 (4.388 sec/step)
# INFO:tensorflow:global step 482: loss = 3.9933 (4.410 sec/step)
# INFO:tensorflow:global step 483: loss = 4.1506 (4.363 sec/step)
# INFO:tensorflow:global step 484: loss = 4.6089 (4.407 sec/step)
# INFO:tensorflow:global step 485: loss = 4.1431 (4.358 sec/step)
# INFO:tensorflow:global step 486: loss = 3.6294 (4.369 sec/step)
# INFO:tensorflow:global step 487: loss = 4.1630 (4.428 sec/step)
# INFO:tensorflow:global step 488: loss = 3.4517 (4.389 sec/step)
# INFO:tensorflow:global step 489: loss = 4.0369 (4.393 sec/step)
# INFO:tensorflow:global step 490: loss = 4.2674 (4.365 sec/step)
# INFO:tensorflow:global step 491: loss = 3.7297 (4.429 sec/step)
# INFO:tensorflow:global step 492: loss = 4.5360 (4.428 sec/step)
# INFO:tensorflow:global step 493: loss = 3.5678 (6.083 sec/step)
# INFO:tensorflow:Recording summary at step 493.
# INFO:tensorflow:global step 494: loss = 4.2457 (5.885 sec/step)
# INFO:tensorflow:global step 495: loss = 4.0118 (4.380 sec/step)
# INFO:tensorflow:global step 496: loss = 4.2108 (4.403 sec/step)
# INFO:tensorflow:global step 497: loss = 4.7751 (4.401 sec/step)
# INFO:tensorflow:global step 498: loss = 4.6603 (4.365 sec/step)
# INFO:tensorflow:global step 499: loss = 4.5609 (4.384 sec/step)
# INFO:tensorflow:global step 500: loss = 4.4162 (4.368 sec/step)
# INFO:tensorflow:global step 501: loss = 4.2371 (4.382 sec/step)
# INFO:tensorflow:global step 502: loss = 4.0489 (4.384 sec/step)
# INFO:tensorflow:global step 503: loss = 3.6411 (4.367 sec/step)
# INFO:tensorflow:global step 504: loss = 3.9622 (4.406 sec/step)
# INFO:tensorflow:global step 505: loss = 3.3123 (4.378 sec/step)
# INFO:tensorflow:global step 506: loss = 4.2863 (4.396 sec/step)
# INFO:tensorflow:global step 507: loss = 4.2512 (4.400 sec/step)
# ...
# INFO:tensorflow:global step 3232: loss = 2.7243 (4.491 sec/step)
# INFO:tensorflow:global step 3233: loss = 2.4261 (4.392 sec/step)
# INFO:tensorflow:global step 3234: loss = 2.7440 (4.451 sec/step)
# INFO:tensorflow:global step 3235: loss = 2.7526 (4.354 sec/step)
# INFO:tensorflow:global step 3236: loss = 3.4613 (4.393 sec/step)
# INFO:tensorflow:global step 3237: loss = 2.6351 (4.425 sec/step)
# INFO:tensorflow:global step 3238: loss = 2.5214 (4.374 sec/step)
# INFO:tensorflow:global step 3239: loss = 2.7507 (4.442 sec/step)
# INFO:tensorflow:global step 3240: loss = 2.2847 (4.394 sec/step)
# INFO:tensorflow:global step 3241: loss = 2.9104 (4.328 sec/step)
# INFO:tensorflow:global step 3242: loss = 2.2381 (4.391 sec/step)
# INFO:tensorflow:global step 3243: loss = 2.3612 (4.418 sec/step)
# INFO:tensorflow:global step 3244: loss = 3.4581 (4.451 sec/step)
# INFO:tensorflow:global step 3245: loss = 2.4164 (4.445 sec/step)
# INFO:tensorflow:global step 3246: loss = 2.9147 (4.472 sec/step)
# INFO:tensorflow:global step 3247: loss = 2.6531 (4.458 sec/step)
# INFO:tensorflow:global step 3248: loss = 2.7534 (4.414 sec/step)
# INFO:tensorflow:global step 3249: loss = 2.7702 (4.462 sec/step)
# INFO:tensorflow:global step 3250: loss = 1.9332 (4.364 sec/step)
# INFO:tensorflow:global step 3251: loss = 2.7143 (4.444 sec/step)
# INFO:tensorflow:global step 3252: loss = 3.1319 (4.415 sec/step)
# INFO:tensorflow:global step 3253: loss = 2.0794 (4.420 sec/step)
# INFO:tensorflow:global step 3254: loss = 2.6111 (4.405 sec/step)
# INFO:tensorflow:global step 3255: loss = 2.8146 (4.397 sec/step)
# INFO:tensorflow:global step 3256: loss = 2.6918 (4.355 sec/step)
# INFO:tensorflow:global step 3257: loss = 2.7703 (5.968 sec/step)
# INFO:tensorflow:Recording summary at step 3257.
# INFO:tensorflow:global step 3258: loss = 2.2314 (5.831 sec/step)
# INFO:tensorflow:global step 3259: loss = 3.1003 (4.411 sec/step)
# INFO:tensorflow:global step 3260: loss = 2.6402 (4.380 sec/step)
# INFO:tensorflow:global step 3261: loss = 2.8935 (4.449 sec/step)
# INFO:tensorflow:global step 3262: loss = 2.7544 (4.403 sec/step)
# INFO:tensorflow:global step 3263: loss = 2.5101 (4.413 sec/step)
# INFO:tensorflow:global step 3264: loss = 2.4348 (4.443 sec/step)
# INFO:tensorflow:global step 3265: loss = 2.3624 (4.425 sec/step)
# INFO:tensorflow:global step 3266: loss = 2.4773 (4.426 sec/step)
# INFO:tensorflow:global step 3267: loss = 2.2704 (4.407 sec/step)
# INFO:tensorflow:global step 3268: loss = 2.9085 (4.439 sec/step)
# INFO:tensorflow:global step 3269: loss = 1.8382 (4.367 sec/step)
# INFO:tensorflow:global step 3270: loss = 2.1851 (4.395 sec/step)
# INFO:tensorflow:global step 3271: loss = 3.0001 (4.464 sec/step)
# INFO:tensorflow:global step 3272: loss = 3.1211 (4.475 sec/step)
# INFO:tensorflow:global step 3273: loss = 2.4611 (4.414 sec/step)
# INFO:tensorflow:global step 3274: loss = 2.7634 (4.480 sec/step)
# INFO:tensorflow:global step 3275: loss = 2.5236 (4.445 sec/step)
# INFO:tensorflow:global step 3276: loss = 2.7160 (4.481 sec/step)
# INFO:tensorflow:global step 3277: loss = 2.9470 (4.476 sec/step)
# INFO:tensorflow:global step 3278: loss = 2.9229 (4.374 sec/step)
# INFO:tensorflow:global step 3279: loss = 2.2509 (4.392 sec/step)
# INFO:tensorflow:global step 3280: loss = 3.4418 (4.416 sec/step)
# INFO:tensorflow:global step 3281: loss = 2.4402 (4.478 sec/step)
# INFO:tensorflow:global step 3282: loss = 2.9658 (4.392 sec/step)
# INFO:tensorflow:Saving checkpoint to path training/model.ckpt
# INFO:tensorflow:global step 3283: loss = 2.7295 (4.457 sec/step)
# INFO:tensorflow:global step 3284: loss = 2.0943 (9.260 sec/step)
# INFO:tensorflow:Recording summary at step 3284.
# INFO:tensorflow:global step 3285: loss = 3.2127 (4.425 sec/step)
# INFO:tensorflow:global step 3286: loss = 3.3892 (4.385 sec/step)
# INFO:tensorflow:global step 3287: loss = 3.2637 (4.483 sec/step)
# INFO:tensorflow:global step 3288: loss = 2.8147 (4.483 sec/step)
# INFO:tensorflow:global step 3289: loss = 3.1858 (4.411 sec/step)
# INFO:tensorflow:global step 3290: loss = 2.5109 (4.378 sec/step)
# INFO:tensorflow:global step 3291: loss = 2.6696 (4.479 sec/step)
# INFO:tensorflow:global step 3292: loss = 1.8183 (4.466 sec/step)
# INFO:tensorflow:global step 3293: loss = 2.6209 (4.743 sec/step)
# INFO:tensorflow:global step 3294: loss = 2.7899 (4.527 sec/step)
# INFO:tensorflow:global step 3295: loss = 2.4573 (4.466 sec/step)
# INFO:tensorflow:global step 3296: loss = 2.6839 (4.395 sec/step)
# INFO:tensorflow:global step 3297: loss = 2.1470 (4.544 sec/step)
# INFO:tensorflow:global step 3298: loss = 2.5591 (4.505 sec/step)
# INFO:tensorflow:global step 3299: loss = 2.6791 (4.538 sec/step)
# INFO:tensorflow:global step 3300: loss = 3.0124 (4.586 sec/step)
# INFO:tensorflow:global step 3301: loss = 2.8318 (4.518 sec/step)
# INFO:tensorflow:global step 3302: loss = 2.3131 (4.467 sec/step)
# INFO:tensorflow:global step 3303: loss = 2.6046 (4.520 sec/step)
# INFO:tensorflow:global step 3304: loss = 2.1956 (4.460 sec/step)
# INFO:tensorflow:global step 3305: loss = 2.4186 (4.459 sec/step)
# INFO:tensorflow:global step 3306: loss = 2.6916 (4.457 sec/step)
# INFO:tensorflow:global step 3307: loss = 1.8188 (4.433 sec/step)
# INFO:tensorflow:global step 3308: loss = 2.9934 (4.474 sec/step)
# INFO:tensorflow:global step 3309: loss = 2.2581 (5.273 sec/step)
# INFO:tensorflow:Recording summary at step 3309.
# INFO:tensorflow:global step 3310: loss = 2.5385 (6.631 sec/step)
# INFO:tensorflow:global step 3311: loss = 2.7680 (4.384 sec/step)
# INFO:tensorflow:global step 3312: loss = 1.9779 (4.532 sec/step)
# INFO:tensorflow:global step 3313: loss = 2.2003 (4.489 sec/step)
# INFO:tensorflow:global step 3314: loss = 2.9912 (4.528 sec/step)
# INFO:tensorflow:global step 3315: loss = 3.4242 (4.436 sec/step)
# INFO:tensorflow:global step 3316: loss = 2.6376 (4.461 sec/step)
# INFO:tensorflow:global step 3317: loss = 2.4703 (4.483 sec/step)
# INFO:tensorflow:global step 3318: loss = 2.3499 (4.470 sec/step)
# INFO:tensorflow:global step 3319: loss = 2.1434 (4.381 sec/step)
# INFO:tensorflow:global step 3320: loss = 2.3578 (4.418 sec/step)
# INFO:tensorflow:global step 3321: loss = 2.4753 (4.414 sec/step)
# INFO:tensorflow:global step 3322: loss = 3.4993 (4.435 sec/step)
# INFO:tensorflow:global step 3323: loss = 2.9447 (4.415 sec/step)
# INFO:tensorflow:global step 3324: loss = 2.6702 (4.430 sec/step)
# INFO:tensorflow:global step 3325: loss = 2.6411 (4.402 sec/step)
# INFO:tensorflow:global step 3326: loss = 2.9261 (4.383 sec/step)
# INFO:tensorflow:global step 3327: loss = 2.1663 (4.450 sec/step)
# INFO:tensorflow:global step 3328: loss = 2.9453 (4.435 sec/step)
# INFO:tensorflow:global step 3329: loss = 2.3412 (4.416 sec/step)
# INFO:tensorflow:global step 3330: loss = 3.0365 (4.430 sec/step)
# INFO:tensorflow:global step 3331: loss = 2.8135 (4.403 sec/step)
# INFO:tensorflow:global step 3332: loss = 3.0892 (4.461 sec/step)
# INFO:tensorflow:global step 3333: loss = 2.4996 (4.366 sec/step)
# INFO:tensorflow:global step 3334: loss = 2.1356 (4.415 sec/step)
# INFO:tensorflow:global step 3335: loss = 1.8883 (4.741 sec/step)
# INFO:tensorflow:Recording summary at step 3335.
# INFO:tensorflow:global step 3336: loss = 2.4571 (7.342 sec/step)
# INFO:tensorflow:global step 3337: loss = 2.3076 (4.385 sec/step)
# INFO:tensorflow:global step 3338: loss = 2.3254 (4.428 sec/step)
# INFO:tensorflow:global step 3339: loss = 2.8650 (4.436 sec/step)
# INFO:tensorflow:global step 3340: loss = 2.2072 (4.408 sec/step)
# INFO:tensorflow:global step 3341: loss = 3.3679 (4.416 sec/step)
# INFO:tensorflow:global step 3342: loss = 2.5506 (4.470 sec/step)
# INFO:tensorflow:global step 3343: loss = 2.6884 (4.369 sec/step)
# INFO:tensorflow:global step 3344: loss = 2.8796 (4.387 sec/step)
# INFO:tensorflow:global step 3345: loss = 2.4145 (4.405 sec/step)
# INFO:tensorflow:global step 3346: loss = 3.2178 (4.429 sec/step)
# INFO:tensorflow:global step 3347: loss = 2.5734 (4.492 sec/step)
# INFO:tensorflow:global step 3348: loss = 2.4197 (4.413 sec/step)
# INFO:tensorflow:global step 3349: loss = 2.5231 (4.426 sec/step)
# INFO:tensorflow:global step 3350: loss = 2.3127 (4.417 sec/step)
# INFO:tensorflow:global step 3351: loss = 2.1007 (4.426 sec/step)
# INFO:tensorflow:global step 3352: loss = 2.5025 (4.788 sec/step)
# INFO:tensorflow:global step 3353: loss = 2.6396 (4.475 sec/step)
# INFO:tensorflow:global step 3354: loss = 2.3134 (4.535 sec/step)
# INFO:tensorflow:global step 3355: loss = 2.3049 (4.406 sec/step)
# INFO:tensorflow:global step 3356: loss = 2.9898 (4.521 sec/step)
# INFO:tensorflow:global step 3357: loss = 2.4051 (4.544 sec/step)
# INFO:tensorflow:global step 3358: loss = 2.8228 (4.517 sec/step)
# INFO:tensorflow:global step 3359: loss = 2.4540 (4.533 sec/step)
# INFO:tensorflow:global step 3360: loss = 2.6828 (4.526 sec/step)
# INFO:tensorflow:global step 3361: loss = 3.1537 (4.513 sec/step)
# INFO:tensorflow:global step 3362: loss = 2.3319 (6.999 sec/step)
# INFO:tensorflow:Recording summary at step 3362.
# INFO:tensorflow:global step 3363: loss = 3.2211 (4.514 sec/step)
# INFO:tensorflow:global step 3364: loss = 1.8921 (4.437 sec/step)
# INFO:tensorflow:global step 3365: loss = 2.2854 (4.405 sec/step)
# INFO:tensorflow:global step 3366: loss = 2.3640 (4.422 sec/step)
# INFO:tensorflow:global step 3367: loss = 2.4186 (4.394 sec/step)
# INFO:tensorflow:global step 3368: loss = 2.2414 (4.436 sec/step)
# INFO:tensorflow:global step 3369: loss = 1.9313 (4.472 sec/step)
# INFO:tensorflow:global step 3370: loss = 2.6415 (4.507 sec/step)
# INFO:tensorflow:global step 3371: loss = 2.7099 (4.471 sec/step)
# INFO:tensorflow:global step 3372: loss = 2.4523 (4.440 sec/step)
# INFO:tensorflow:global step 3373: loss = 2.2093 (4.407 sec/step)
# INFO:tensorflow:global step 3374: loss = 2.7315 (4.453 sec/step)
# INFO:tensorflow:global step 3375: loss = 2.0197 (4.417 sec/step)
# INFO:tensorflow:global step 3376: loss = 2.7637 (4.434 sec/step)
# INFO:tensorflow:global step 3377: loss = 2.4936 (4.416 sec/step)
# INFO:tensorflow:global step 3378: loss = 2.8061 (4.407 sec/step)
# INFO:tensorflow:global step 3379: loss = 3.0079 (4.441 sec/step)
# INFO:tensorflow:global step 3380: loss = 2.0413 (4.504 sec/step)
# INFO:tensorflow:global step 3381: loss = 2.2885 (4.497 sec/step)
# INFO:tensorflow:global step 3382: loss = 2.9038 (4.476 sec/step)
# INFO:tensorflow:global step 3383: loss = 2.4625 (4.460 sec/step)
# INFO:tensorflow:global step 3384: loss = 2.7334 (4.427 sec/step)
# INFO:tensorflow:global step 3385: loss = 2.1759 (4.450 sec/step)
# INFO:tensorflow:global step 3386: loss = 2.2143 (4.418 sec/step)
# INFO:tensorflow:global step 3387: loss = 2.8507 (4.463 sec/step)
# INFO:tensorflow:global step 3388: loss = 2.2490 (6.484 sec/step)
# INFO:tensorflow:Recording summary at step 3388.
# INFO:tensorflow:global step 3389: loss = 2.3700 (5.525 sec/step)
# INFO:tensorflow:global step 3390: loss = 2.3958 (4.441 sec/step)
# INFO:tensorflow:global step 3391: loss = 3.1474 (4.492 sec/step)
# INFO:tensorflow:global step 3392: loss = 2.5446 (4.397 sec/step)
# INFO:tensorflow:global step 3393: loss = 2.5811 (4.403 sec/step)
# INFO:tensorflow:global step 3394: loss = 2.1146 (4.401 sec/step)
# INFO:tensorflow:global step 3395: loss = 2.3778 (4.418 sec/step)
# INFO:tensorflow:global step 3396: loss = 2.4588 (4.488 sec/step)
# INFO:tensorflow:global step 3397: loss = 2.3231 (4.460 sec/step)
# INFO:tensorflow:global step 3398: loss = 2.2924 (4.411 sec/step)
# INFO:tensorflow:global step 3399: loss = 3.2587 (4.397 sec/step)
# INFO:tensorflow:global step 3400: loss = 2.4921 (4.377 sec/step)
# INFO:tensorflow:global step 3401: loss = 2.6669 (4.390 sec/step)
# INFO:tensorflow:global step 3402: loss = 2.4673 (4.399 sec/step)
# INFO:tensorflow:global step 3403: loss = 2.9174 (4.392 sec/step)
# INFO:tensorflow:global step 3404: loss = 2.2099 (4.451 sec/step)
# INFO:tensorflow:global step 3405: loss = 2.4332 (4.431 sec/step)
# INFO:tensorflow:global step 3406: loss = 2.5371 (4.437 sec/step)
# INFO:tensorflow:global step 3407: loss = 2.3772 (4.410 sec/step)
# INFO:tensorflow:global step 3408: loss = 2.7707 (4.406 sec/step)
# INFO:tensorflow:global step 3409: loss = 2.7279 (4.398 sec/step)
# INFO:tensorflow:global step 3410: loss = 2.4731 (4.384 sec/step)
# INFO:tensorflow:global step 3411: loss = 2.1886 (4.412 sec/step)
# INFO:tensorflow:global step 3412: loss = 1.8712 (4.422 sec/step)
# INFO:tensorflow:global step 3413: loss = 2.6495 (4.520 sec/step)
# INFO:tensorflow:Saving checkpoint to path training/model.ckpt
# INFO:tensorflow:global step 3414: loss = 2.8078 (4.895 sec/step)
# INFO:tensorflow:Recording summary at step 3414.
# INFO:tensorflow:global step 3415: loss = 2.3166 (8.708 sec/step)
# INFO:tensorflow:global step 3416: loss = 2.5991 (4.412 sec/step)
# INFO:tensorflow:global step 3417: loss = 2.4330 (4.440 sec/step)
# INFO:tensorflow:global step 3418: loss = 2.1752 (4.460 sec/step)
# INFO:tensorflow:global step 3419: loss = 2.3508 (4.427 sec/step)
# INFO:tensorflow:global step 3420: loss = 3.3051 (4.423 sec/step)
# INFO:tensorflow:global step 3421: loss = 2.5420 (4.443 sec/step)
# INFO:tensorflow:global step 3422: loss = 2.3311 (4.484 sec/step)
# INFO:tensorflow:global step 3423: loss = 2.4978 (4.471 sec/step)
# INFO:tensorflow:global step 3424: loss = 3.0433 (4.440 sec/step)
# INFO:tensorflow:global step 3425: loss = 2.5832 (4.379 sec/step)
# INFO:tensorflow:global step 3426: loss = 2.6410 (4.448 sec/step)
# INFO:tensorflow:global step 3427: loss = 2.9589 (4.456 sec/step)
# INFO:tensorflow:global step 3428: loss = 2.6278 (4.434 sec/step)
# INFO:tensorflow:global step 3429: loss = 2.9109 (4.454 sec/step)
# INFO:tensorflow:global step 3430: loss = 2.7971 (4.472 sec/step)
# INFO:tensorflow:global step 3431: loss = 1.8574 (4.428 sec/step)
# INFO:tensorflow:global step 3432: loss = 2.6072 (4.429 sec/step)
# INFO:tensorflow:global step 3433: loss = 3.1809 (4.361 sec/step)
# INFO:tensorflow:global step 3434: loss = 2.9578 (4.432 sec/step)
# INFO:tensorflow:global step 3435: loss = 2.0751 (4.414 sec/step)
# INFO:tensorflow:global step 3436: loss = 2.6423 (4.413 sec/step)
# INFO:tensorflow:global step 3437: loss = 2.8607 (4.563 sec/step)
# INFO:tensorflow:global step 3438: loss = 2.2678 (4.490 sec/step)
# INFO:tensorflow:global step 3439: loss = 2.7407 (4.417 sec/step)
# INFO:tensorflow:global step 3440: loss = 2.6662 (4.998 sec/step)
# INFO:tensorflow:Recording summary at step 3440.
# INFO:tensorflow:global step 3441: loss = 2.1159 (7.062 sec/step)
# INFO:tensorflow:global step 3442: loss = 2.4478 (4.519 sec/step)
# INFO:tensorflow:global step 3443: loss = 2.1370 (4.440 sec/step)
# INFO:tensorflow:global step 3444: loss = 3.1217 (4.460 sec/step)
# INFO:tensorflow:global step 3445: loss = 1.6949 (4.393 sec/step)
# INFO:tensorflow:global step 3446: loss = 2.4442 (4.441 sec/step)
# INFO:tensorflow:global step 3447: loss = 3.1775 (4.410 sec/step)
# INFO:tensorflow:global step 3448: loss = 2.8204 (4.534 sec/step)
# INFO:tensorflow:global step 3449: loss = 2.4245 (4.472 sec/step)
# INFO:tensorflow:global step 3450: loss = 2.8649 (4.439 sec/step)
# INFO:tensorflow:global step 3451: loss = 2.5365 (4.425 sec/step)
# INFO:tensorflow:global step 3452: loss = 3.1285 (4.472 sec/step)
# INFO:tensorflow:global step 3453: loss = 1.9719 (4.420 sec/step)
# INFO:tensorflow:global step 3454: loss = 2.6832 (4.417 sec/step)
# INFO:tensorflow:global step 3455: loss = 2.0985 (4.412 sec/step)
# INFO:tensorflow:global step 3456: loss = 2.3179 (4.387 sec/step)
# INFO:tensorflow:global step 3457: loss = 2.1164 (4.491 sec/step)
# INFO:tensorflow:global step 3458: loss = 2.6060 (4.462 sec/step)
# INFO:tensorflow:global step 3459: loss = 2.8833 (4.493 sec/step)
# INFO:tensorflow:global step 3460: loss = 2.4984 (4.428 sec/step)
# INFO:tensorflow:global step 3461: loss = 3.1952 (4.422 sec/step)
# INFO:tensorflow:global step 3462: loss = 2.6878 (4.407 sec/step)
# INFO:tensorflow:global step 3463: loss = 2.0782 (4.438 sec/step)
# INFO:tensorflow:global step 3464: loss = 2.6335 (4.474 sec/step)
# INFO:tensorflow:global step 3465: loss = 2.7125 (4.433 sec/step)
# INFO:tensorflow:global step 3466: loss = 2.4584 (4.498 sec/step)
# INFO:tensorflow:Recording summary at step 3466.
# INFO:tensorflow:global step 3467: loss = 2.5198 (7.582 sec/step)
# INFO:tensorflow:global step 3468: loss = 2.5950 (4.503 sec/step)

# %% [markdown]
# After training is complete you will need to know the number from the latest checkpoint for the next few steps. The number you are looking for looks like this from the files in the training folder: model.ckpt-4696.index

# %%
ls -al training
# Out:
# ls: cannot access 'training': No such file or directory

# %% [markdown]
# OPTIONAL: zip the training folder and download it in case you want to restart traing at another time

# %%
### OPTIONAL, if you want to continue training sometimes later ###
# Zip the training folder and download locally, so we can continue in another session if required
# !zip -r 'training4696.zip' ./training

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path /content/tensorflow1/models/research/object_detection/training/pipeline.config --trained_checkpoint_prefix training/model.ckpt-4696 --output_directory trained_inference_graph/

# %% [markdown]
# # CREATE frozen_inference_graph.pb

# %% [markdown]
# A frozen inference graph can be used on a wide variety of machines and after you create one you can use the next steps to test it here in Colab against the test images or you can upload your own to the /test_images folder if you want.
#
# You will need the number of the latest training checkpoint in this command so be sure you have found it in the preceding steps.  Look for the latest step number in the training folder and replace the number here in the parameters with the step number from your folder:
# --trained_checkpoint_prefix training/model.ckpt-**13144**

# %%
# !mkdir inference_graph
# export .pd file for windows
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path=/content/tensorflow1/models/research/object_detection/training/pipeline.config --trained_checkpoint_prefix training/model.ckpt-4696 --output_directory inference_graph

# %%
# frozen_inference_graph.pb
### OPTIONAL ###
# Zip the inference_graph folder, and backup to GDrive, so we can use it for normal predictions on windows
# !zip -r 'inference_graph4696.zip' ./inference_graph   VB

# %% [markdown]
# #Use the frozen_inference_graph.pb to visually verify the model works
#
# Move to the /research folder to run the code below and use the frozen inference graph created in the steps above. This .pb file can be used on many different types of machines including linux, mac and windows.

# %%
#!pwd
# %cd /content/tensorflow1/models/research

# %% [markdown]
# Next set the code to use the frozen_inference_graph.pb created in the steps above and to use the label map used in training the model.

# %%
# run from /content/tensorflow1/models/research

from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util


# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_FROZEN_GRAPH = 'object_detection/inference_graph/frozen_inference_graph.pb'

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = '/content/tensorflow1/models/research/object_detection/Recycle-Item-Detection/training/labelmap.pbtxt'


print(PATH_TO_FROZEN_GRAPH)
print(PATH_TO_LABELS)

# %% [markdown]
# Below is some boiler plate code to setup the Colab to run the inference on local images.

# %%
# Load a (frozen) Tensorflow model into memory.
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_FROZEN_GRAPH, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# Loading label map
# Label maps map indices to category names, so that when our convolution network predicts 5, we know that this corresponds to airplane. Here we use internal utility functions, 
# but anything that returns a dictionary mapping integers to appropriate string labels would be fine
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# helper code
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)


def run_inference_for_single_image(image, graph):
  with graph.as_default():
    with tf.Session(config=config) as sess:
      # Get handles to input and output tensors
      ops = tf.get_default_graph().get_operations()
      all_tensor_names = {output.name for op in ops for output in op.outputs}
      tensor_dict = {}
      for key in [
          'num_detections', 'detection_boxes', 'detection_scores',
          'detection_classes', 'detection_masks'
      ]:
        tensor_name = key + ':0'
        if tensor_name in all_tensor_names:
          tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
              tensor_name)
      if 'detection_masks' in tensor_dict:
        # The following processing is only for single image
        detection_boxes = tf.squeeze(tensor_dict['detection_boxes'], [0])
        detection_masks = tf.squeeze(tensor_dict['detection_masks'], [0])
        # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
        real_num_detection = tf.cast(tensor_dict['num_detections'][0], tf.int32)
        detection_boxes = tf.slice(detection_boxes, [0, 0], [real_num_detection, -1])
        detection_masks = tf.slice(detection_masks, [0, 0, 0], [real_num_detection, -1, -1])
        detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
            detection_masks, detection_boxes, image.shape[0], image.shape[1])
        detection_masks_reframed = tf.cast(
            tf.greater(detection_masks_reframed, 0.5), tf.uint8)
        # Follow the convention by adding back the batch dimension
        tensor_dict['detection_masks'] = tf.expand_dims(
            detection_masks_reframed, 0)
      image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

      # Run inference
      output_dict = sess.run(tensor_dict,
                             feed_dict={image_tensor: np.expand_dims(image, 0)})

      # all outputs are float32 numpy arrays, so convert types as appropriate
      output_dict['num_detections'] = int(output_dict['num_detections'][0])
      output_dict['detection_classes'] = output_dict[
          'detection_classes'][0].astype(np.uint8)
      output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
      output_dict['detection_scores'] = output_dict['detection_scores'][0]
      if 'detection_masks' in output_dict:
        output_dict['detection_masks'] = output_dict['detection_masks'][0]
  return output_dict

# %% [markdown]
# The next block is the code used to draw the color coded boxes around the item that are identified in the images, you will not need to make any edis here, just run it and move on to the next step.

# %%
import collections
import matplotlib; matplotlib.use('Agg')  # pylint: disable=multiple-statements
import matplotlib.pyplot as plt  # pylint: disable=g-import-not-at-top
import numpy as np
import PIL.Image as Image
import PIL.ImageColor as ImageColor
import PIL.ImageDraw as ImageDraw
import PIL.ImageFont as ImageFont
import six
import tensorflow as tf
import numpy as np

def draw_bounding_box_on_image_array(image, ymin, xmin, ymax, xmax, color='red', thickness=4, display_str_list=()):
  image_pil = Image.fromarray(np.uint8(image)).convert('RGB')
  draw_bounding_box_on_image(image_pil, ymin, xmin, ymax, xmax, color, thickness, display_str_list)
  np.copyto(image, np.array(image_pil))

def draw_bounding_box_on_image(image, ymin, xmin, ymax, xmax, color='red', thickness=4, display_str_list=()):
  draw = ImageDraw.Draw(image)
  im_width, im_height = image.size
  (left, right, top, bottom) = (xmin * im_width, xmax * im_width, ymin * im_height, ymax * im_height)
  draw.line([(left, top), (left, bottom), (right, bottom), (right, top), (left, top)], width=thickness, fill=color)
  try:
    font = ImageFont.truetype('arial.ttf', 24)
  except IOError:
    font = ImageFont.load_default()

  # If the total height of the display strings added to the top of the bounding
  # box exceeds the top of the image, stack the strings below the bounding box
  # instead of above.
  display_str_heights = [font.getsize(ds)[1] for ds in display_str_list]
  # Each display_str has a top and bottom margin of 0.05x.
  total_display_str_height = (1 + 2 * 0.05) * sum(display_str_heights)

  if top > total_display_str_height:
    text_bottom = top
  else:
    text_bottom = bottom + total_display_str_height
  # Reverse list and print from bottom to top.
  for display_str in display_str_list[::-1]:
    text_width, text_height = font.getsize(display_str)
    margin = np.ceil(0.05 * text_height)
    draw.rectangle([(left, text_bottom - text_height - 2 * margin), (left + text_width, text_bottom)], fill=color)
    draw.text((left + margin, text_bottom - text_height - margin), display_str, fill='black', font=font)
    text_bottom -= text_height - 2 * margin

def visualize_boxes_and_labels_on_image_array(image, boxes, classes, scores, category_index, instance_masks=None,
    max_boxes_to_draw=20, min_score_thresh=.5, line_thickness=4, groundtruth_box_visualization_color='black'):
  
  # Create a display string (and color) for every box location, group any boxes
  # that correspond to the same location.
  box_to_display_str_map = collections.defaultdict(list)
  box_to_color_map = collections.defaultdict(str)
  box_to_instance_masks_map = {}
  box_to_instance_boundaries_map = {}
  box_to_keypoints_map = collections.defaultdict(list)

  if not max_boxes_to_draw:
    max_boxes_to_draw = boxes.shape[0]
  for i in range(min(max_boxes_to_draw, boxes.shape[0])):
    if scores is None or scores[i] > min_score_thresh:
      box = tuple(boxes[i].tolist())
      if instance_masks is not None:
        box_to_instance_masks_map[box] = instance_masks[i]
      if scores is None:
        box_to_color_map[box] = groundtruth_box_visualization_color
      else:
        display_str = ''

        if classes[i] in category_index.keys():
          class_name = category_index[classes[i]]['name']
        else:
          class_name = 'N/A'
        display_str = '{}: {}%'.format(display_str, int(100*scores[i]))
        box_to_display_str_map[box].append(display_str)

        box_to_color_map[box] = assigned_color_by_class(classes[i])
        print('scores:', scores[i], ' class: ', category_index[classes[i]]['name'])

  # Draw all boxes onto image.
  for box, color in box_to_color_map.items():
    ymin, xmin, ymax, xmax = box
    draw_bounding_box_on_image_array(image, ymin, xmin, ymax, xmax, color=color, thickness=line_thickness, display_str_list=box_to_display_str_map[box])
  return image

def assigned_color_by_class(class_number):
  if class_number == 1: # cardboard
    color_name = 'Red' # shows as Red
  elif class_number == 2: #glass
    color_name = 'Chartreuse'  #shows as green
  elif
    class_number == 3: #metal
    color_name = 'Blue' #shows blue box
  elif
    class_number == 4: #paper
    color_name == 'Yellow' #shows as yellow
  elif
    class_number == 5: #plastic 
    color_name == 'White' #shows white
  elif
    class_number == 6: #trash
    color_name == 'Orange' #shows orange
  
  return color_name

# %% [markdown]
# The following code will load images to have the model run against. If you want to add images to be tested simply place new images in the /test_images folder and add the path to the image into the array below. These images are loaded and placed in one of the steps above.

# %%
IMAGE_SIZE = (12, 8)
TEST_IMAGE_PATHS = [
  '/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0060.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0079.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0088.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0094.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0100.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0103.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0110.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0117.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0135.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0152.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0170.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0190.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0209.jpg'
  ,'/content/tensorflow1/models/research/object_detection/images/RecycleItemImage/test/recycle0225.jpg'
]

print(TEST_IMAGE_PATHS)
# !pwd

# %% [markdown]
# The last step is to run an inference on each image in the defined array above. The code will first output the image path for each image and then run teh prediction on the image to see if their are any faces and if the face is wearing a mask or not. You can see the score on each prediction in the output. Finally the code will display each image with the boxes and score overlayed and color coded.

# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

for image_path in TEST_IMAGE_PATHS:
  image = Image.open(image_path)

  # the array based representation of the image will be used later in order to prepare the
  # result image with boxes and labels on it.
  image_np = load_image_into_numpy_array(image)

  # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
  image_np_expanded = np.expand_dims(image_np, axis=0)

  # Actual detection.
  output_dict = run_inference_for_single_image(image_np, detection_graph)

  print(image_path)


  # Visualization of the results of a detection.
  visualize_boxes_and_labels_on_image_array(
      image_np,
      output_dict['detection_boxes'],
      output_dict['detection_classes'],
      output_dict['detection_scores'],
      category_index,
      instance_masks=output_dict.get('detection_masks'),
      line_thickness=2,
      min_score_thresh=0.30)
  plt.figure(figsize=IMAGE_SIZE)
  plt.imshow(image_np)

# %% [markdown]
# # Prepare model for Raspberry Pi

# %% [markdown]
# First you will need to create the .pb file setup for tflite and then convert that file to a .tflite .
#
# 1. CREATE tflite_graph.pb file from your last saved checkpoint.

# %%
# %cd /content/tensorflow1/models/research/object_detection/

# %%
# Create TFLite_model folder
# !mkdir TFLite_model
#!mkdir inference_graph

# %% [markdown]
# Code below will make the tflite_graph.pb file using the latest checkpoint (set trained_checkpoint_prefix based on the latest file in the training folder). Make sure you look in the training folder for the checkpoint with the largest number and replace the "model.ckpt-13144" with the number from your latest checkpoint like this "model.ckpt-{YOUR NUMBER VALUE}". When you have done that then run the code.
#
# The parameter you will need to adjust in the command below looks like this:
#
# --trained_checkpoint_prefix=/content/tensorflow1/models/research/object_detection/training/model.ckpt-13144
#
# but the 13144 number will need to be from the files in your /training directory

# %%
# Freeze the TFLite inference graph for using on a RPI
# Change ????? to your checkpoint of choice (probably the largest one that was created after you stopped the training process)
# !python export_tflite_ssd_graph.py --pipeline_config_path=/content/tensorflow1/models/research/object_detection/training/pipeline.config --trained_checkpoint_prefix=/content/tensorflow1/models/research/object_detection/training/model.ckpt-4696 --output_directory=/content/tensorflow1/models/research/object_detection/TFLite_model --add_postprocessing_op=true

# %% [markdown]
# 2. CONVERT .pb file to TFLite to be used on the Raspberry Pi
#
# This detect.tflite can be used on the RPI since it has been converted to TFLite format and can be then run on the lower powered machines like the Raspberry Pi

# %%
# CONVERT USING TOCO
# !rm ./TFLite_model/detect.tflite
# !toco --graph_def_file=/content/tensorflow1/models/research/object_detection/TFLite_model/tflite_graph.pb --output_file=/content/tensorflow1/models/research/object_detection/TFLite_model/detect.tflite --input_arrays=normalized_input_image_tensor --output_arrays=TFLite_Detection_PostProcess,TFLite_Detection_PostProcess:1,TFLite_Detection_PostProcess:2,TFLite_Detection_PostProcess:3 --inference_type=QUANTIZED_UINT8 --mean_values=128 --std_dev_values=128 --change_concat_input_ranges=false --allow_custom_ops --input_shapes=1,300,300,3 --enable_v1_converter

# %% [markdown]
# # Saving models and files created
#
# The best way to have some output of the models you are creating is to zip up the folders and either
#
# 1) download the zip files or
#
# 2) use Google Drive to back up the files to somewhere you can download later.

# %%
# Zip the TFLite_Model folder for downloading
# %cd /content/tensorflow1/models/research/object_detection

# !zip -r 'TFLite_Model081420.zip' TFLite_model

# %% [markdown]
# Next use the code below to mount Google Drive to your Colab so that you can easily save files there (much faster than downloading from Colab).

# %%
# Mount GDrive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !cp  training4696.zip '/content/drive'

# %%
# !cp  TFLite_Model '/content/drive'

# %%
# !cp  inference_graph.zip '/content/drive/My Drive/machine_learning/SSD_TRAINER'

# %% [markdown]
# Then, transfer the .tflite to Raspberry Pi to run on PiCamera
